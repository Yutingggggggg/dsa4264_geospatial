# %%
# %run data.ipynb
# Out:
# ['https://ltafarecard.s3.ap-southeast-1.amazonaws.com/202409/origin_destination_bus_202409.zip?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEDwaDmFwLXNvdXRoZWFzdC0xIkcwRQIhAMmpK6qM%2FrGkpubmtJxAqtbwWwCdzov9jQPqH2i%2FYhoJAiBTCQfAOCqWhgU9koM1MraPn3J01Obn0YysZ8clgxk1IyrLBQil%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAQaDDM0MDY0NTM4MTMwNCIMxsktxanYOshdJX2yKp8FOS%2BbE52%2F1yylJulOknK9y42KoviLtVDuhA2BYWERVcqIhBnGLtTAHLmytIe7qIm950NnQXOWkV5yfhnHr%2BLOz5%2BeJBr8%2BCLRZJ%2BLfds2VeNfo%2FRLvenFVwhFRSvyA25nBPzRnRyUzc%2BBi1G2juhL%2FFppECK7cmfIW1MyH5l5cfDZ1wRZ1PWKVbvJdKxmszh8Enk%2B9d1%2F1kFIJKH5DGdTPqK4RJXA6H7pOw4OO7pzmEjRc4DEdzzHwTBDv%2BxpyEdEiBCjHC6tS0QKPjB%2B7J2jxzkdZrT2hmXJYW%2Bi7ea2cmvBGRb34XMaQLjlex4VP5X9HMt67OLlmtLhWcPAyP%2FMm2rocddaBdfHZ%2FbfhsMKMQ7PGZu4RGGwOENy9OWSg7PqYsE5AZb8G%2Bw4IOlE%2FK%2FedFXL6FMXZwSdXIeK50A6v3%2BGeJABrD88AkboxAuDS2opSmz%2B5HVCVgegmPhko6hO80PHbDFIyDzu%2F9WznxM5hcZZ97YMql5hMeLIIOLuMpx%2FYA3uUPVwyShFkGgZf7Ul6g3gjesO26xcCrqPIWehcM7%2BbkxO0Ch5Nd0z%2BFDggod1RoAOUTfdtbJb7YxZUgVFEmT4CkY%2BmB
# ...

# %%
# bus stops geodataframe
bus_stops_gdf = geopandas.GeoDataFrame(bus_stops, 
                                       geometry = geopandas.points_from_xy(bus_stops.Longitude, bus_stops.Latitude),
                                       crs = "EPSG:4326")
bus_stops_gdf
# Out:
#      BusStopCode           RoadName             Description  Latitude  \
# 0          01012        Victoria St     Hotel Grand Pacific  1.296848
# 1          01013        Victoria St         St. Joseph's Ch  1.297710
# 2          01019        Victoria St         Bras Basah Cplx  1.296990
# 3          01029      Nth Bridge Rd            Opp Natl Lib  1.296673
# 4          01039      Nth Bridge Rd              Bugis Cube  1.298208
# ...          ...                ...                     ...       ...
# 5133       99139  Changi Village Rd                   Blk 5  1.388195
# 5134       99161          Nicoll Dr   Aft Changi Beach CP 3  1.390262
# 5135       99171          Nicoll Dr       Changi Beach CP 2  1.391128
# 5136       99181      Telok Paku Rd  Bef S'pore Aviation Ac  1.387754
# 5137       99189      Telok Paku Rd      S'pore Aviation Ac  1.388414
#
#        Longitude                   geometry
# 0     103.852536  POINT (103.85254 1.29685)
# ...

# %%
# bus routes geodataframe
bus_routes_gdf = geopandas.GeoDataFrame(bus_route_names, 
                                       geometry = geopandas.points_from_xy(bus_route_names.Longitude, bus_route_names.Latitude),
                                       crs = "EPSG:4326")
bus_routes_gdf
# Out:
#       ServiceNo Operator  Direction  StopSequence BusStopCode  Distance  \
# 0            10     SBST          1             1       75009       0.0
# 1            10     SBST          1             2       76059       0.6
# 2            10     SBST          1             3       76069       1.1
# 3            10     SBST          1             4       96289       2.3
# 4            10     SBST          1             5       96109       2.7
# ...         ...      ...        ...           ...         ...       ...
# 25539        9B     SBST          1            25       95091       9.5
# 25540        9B     SBST          1            26       95131       9.7
# 25541        9B     SBST          1            27       95141      10.2
# 25542        9B     SBST          1            28       95061      10.6
# 25543        9B     SBST          1            29       95051      11.0
#
#       WD_FirstBus WD_LastBus SAT_FirstBus SAT_LastBus SUN_FirstBus  \
# ...

# %%
# train station exits geodataframe
train_station_exits_gdf = geopandas.read_file('/Users/jiyadutta/Desktop/DSA4264/TrainStationExit/Train_Station_Exit_Layer.shp')
train_station_exits_gdf
# Out:
#                        stn_name exit_code                     geometry
# 0        MACPHERSON MRT STATION    Exit A  POINT (34285.068 34322.985)
# 1        MACPHERSON MRT STATION    Exit B  POINT (34382.153 34231.904)
# 2        MACPHERSON MRT STATION    Exit C  POINT (34337.292 34190.603)
# 3          TONGKANG LRT STATION    Exit B  POINT (33872.145 41256.053)
# 4          TONGKANG LRT STATION    Exit A  POINT (33858.542 41234.065)
# ..                          ...       ...                          ...
# 588        BAYSHORE MRT STATION    Exit 2  POINT (39947.586 32720.398)
# 589        BAYSHORE MRT STATION    Exit 3  POINT (39952.869 32873.448)
# 590        BAYSHORE MRT STATION    Exit 4  POINT (40170.433 32868.859)
# 591        BAYSHORE MRT STATION    Exit 5  POINT (40160.253 32799.231)
# 592  TANJONG KATONG MRT STATION    Exit 3  POINT (35166.777 31398.349)
#
# [593 rows x 3 columns]

# %%
bus_routes_gdf_3857 = bus_routes_gdf.to_crs(3857)
train_station_exits_gdf_3857 = train_station_exits_gdf.to_crs(3857)

nearest_train_station_output = []
for i, row in tqdm(bus_routes_gdf_3857.iterrows()):

    # Compute the distance from each bus stop to all train station exits
    distances = train_station_exits_gdf_3857.distance(row['geometry'])

    nearest_train_station_output.append({
        'Bus Service': row['ServiceNo'],
        'Route Direction': row['Direction'],
        'Bus Stop Code': row['BusStopCode'],
        'Description': row['Description'],
        'Nearest Train Station': train_station_exits_gdf_3857.loc[int(distances.argmin()), 'stn_name'],
        'Distance': float(distances.min())
    })

nearest_train_stations = pd.DataFrame(nearest_train_station_output)
nearest_train_stations
# Out:
# 25544it [00:07, 3252.70it/s]
#       Bus Service  Route Direction Bus Stop Code           Description  \
# 0              10                1         75009          Tampines Int
# 1              10                1         76059  Opp Our Tampines Hub
# 2              10                1         76069               Blk 147
# 3              10                1         96289   Changi General Hosp
# 4              10                1         96109          Opp Blk 3012
# ...           ...              ...           ...                   ...
# 25539          9B                1         95091         SAF Ferry Ter
# 25540          9B                1         95131       Police Pass Off
# 25541          9B                1         95141      Aft Cargo Bldg D
# 25542          9B                1         95061           Airline Hse
# 25543          9B                1         95051      3rd Cargo Agents
#
#             Nearest Train Station     Distance
# ...

# %%
bus_stops_with_mrt = nearest_train_stations[nearest_train_stations['Distance'] < 150]
number_of_mrt = bus_stops_with_mrt.groupby(['Bus Service', 'Route Direction']).size().reset_index(name = 'Count')
number_of_mrt.sort_values('Count', ascending = False)
# Out:
#     Bus Service  Route Direction  Count
# 342          36                1     29
# 433          63                1     28
# 670        972M                1     27
# 344         36B                1     26
# 468          67                1     24
# ..          ...              ...    ...
# 383          46                1      1
# 533         84A                1      1
# 382         45A                1      1
# 369         403                1      1
# 487         70B                1      1
#
# [710 rows x 3 columns]

# %%
# overlapping bus stops 
# overlap_counts = nearest_train_stations.groupby(['Bus Service', 'Route Direction']).size().reset_index(name='Count')
# overlap_counts_sorted = overlap_counts.sort_values('Count', ascending=False)
# overlap_counts_sorted.head()
# Out:
#     Bus Service  Route Direction  Count
# 497         70M                1    105
# 442          63                1    102
# 258          24                1    100
# 405          51                1     98
# 603          89                1     95

# %%
bus_stops_with_mrt[bus_stops_with_mrt['Bus Service'] == "960"]
# Out:
#       Bus Service  Route Direction Bus Stop Code                Description  \
# 22974         960                1         46009              Woodlands Int
# 22977         960                1         46529          Opp Marsiling Stn
# 22980         960                1         45139                 Kranji Stn
# 22995         960                1         44049            Opp Junction 10
# 22998         960                1         44201              Aft Petir Stn
# 23000         960                1         44221            Opp Pending Stn
# 23002         960                1         40239     BEF STEVENS STN EXIT 4
# 23003         960                1         40089     AFT STEVENS STN EXIT 5
# 23008         960                1         40049      Opp Newton Stn Exit C
# 23012         960                1         40019           Little India Stn
# 23013         960                1         07539      Bef Rochor Stn Exit B
# ...

# %%
# import folium
# map_sg = folium.Map(location=[1.3521, 103.8198], zoom_start=12)


# for index, row in bus_volume_coordinates.iterrows():
#     origin = [row['Origin Latitude'], row['Origin Longitude']]
#     destination = [row['Destination Latitude'], row['Destination Longitude']]
#     volume = row['TOTAL_TRIPS']
#     folium.PolyLine(locations=[origin, destination], color='blue', weight=2).add_to(map_sg)
#     folium.CircleMarker(location=origin, radius=volume/1000, color='green', fill=True, fill_color='green').add_to(map_sg)
#     folium.CircleMarker(location=destination, radius=volume/1000, color='red', fill=True, fill_color='red').add_to(map_sg)

# # Display the map
# map_sg
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 7
#       4 map_sg = folium.Map(location=[1.3521, 103.8198], zoom_start=12)
#       6 # Add bus routes and volume markers
# ----> 7 for index, row in bus_volume_coordinates.iterrows():
#       8     origin = [row['Origin Latitude'], row['Origin Longitude']]
#       9     destination = [row['Destination Latitude'], row['Destination Longitude']]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1399, in DataFrame.iterrows(self)
#    1397 klass = self._constructor_sliced
#    1398 using_cow = using_copy_on_write()
# -> 1399 for k, v in zip(self.index, self.values):
#    1400     s = klass(v, index=columns, name=k).__finalize__(self)
#    1401     if using_cow and self._mgr.is_single_block:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:11360, in DataFrame.values(self)
# ...

# %%
import geopandas as gpd
import pandas as pd
from tqdm import tqdm
from shapely.geometry import Point

def calculate_distance_to_mrt(bus_volume_coordinates, train_station_exits_gdf):
    # Bus origin points
    bus_origin_gdf = gpd.GeoDataFrame(bus_volume_coordinates, 
                                      geometry=gpd.points_from_xy(bus_volume_coordinates['Origin Longitude'], bus_volume_coordinates['Origin Latitude']),
                                      crs="EPSG:4326")
    bus_origin_gdf_3857 = bus_origin_gdf.to_crs(3857)
    train_station_exits_gdf_3857 = train_station_exits_gdf.to_crs(3857)
    
    score = []
    for i, row in tqdm(bus_origin_gdf_3857.iterrows(), total=bus_origin_gdf_3857.shape[0]):
        distances = train_station_exits_gdf_3857.distance(row['geometry'])
        min_distance = float(distances.min())
        nearest_station = train_station_exits_gdf_3857.loc[distances.idxmin(), 'stn_name']
        
        score.append({
            'ORIGIN_PT_CODE': row['ORIGIN_PT_CODE'],
            'Origin Latitude': row['Origin Latitude'],
            'Origin Longitude': row['Origin Longitude'],
            'Nearest MRT Station': nearest_station,
            'Distance to Nearest MRT': min_distance
        })
    
    return pd.DataFrame(score)

# Closer = higher score
def normalize(df, distance_col):
    max_distance = df[distance_col].max()
    df['Normalized Distance'] = 1 - (df[distance_col] / max_distance)  
    return df

# Incorporate Passenger volume (TOTAL_TRIPS)
def compute_weighted_overlap(bus_volume_coordinates, overlap_df, volume_col='TOTAL_TRIPS'):
    bus_overlap = pd.merge(bus_volume_coordinates, overlap_df, on='ORIGIN_PT_CODE')
    
    # Formula for weighted score
    bus_overlap['Weighted Overlap'] = bus_overlap['Normalized Distance'] * bus_overlap[volume_col]
    route_overlap_scores = bus_overlap.groupby(['ORIGIN_PT_CODE']).agg(
        total_overlap=pd.NamedAgg(column='Weighted Overlap', aggfunc='sum'),
        avg_overlap=pd.NamedAgg(column='Weighted Overlap', aggfunc='mean'),
        total_volume=pd.NamedAgg(column=volume_col, aggfunc='sum')
    ).reset_index()

    return route_overlap_scores

overlap_df = calculate_distance_to_mrt(bus_volume_coordinates, train_station_exits_gdf)
normalized_overlap_df = normalize(overlap_df, 'Distance to Nearest MRT')
route_overlap_scores = compute_weighted_overlap(bus_volume_coordinates, normalized_overlap_df)
sorted_routes = route_overlap_scores.sort_values(by='total_overlap', ascending=False)
# Out:
# 100%|██████████| 5721503/5721503 [28:37<00:00, 3331.49it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Passenger Volume
# Group bus_volume by the ORIGIN_PT_CODE and sum up to get the total number of trips for each bus stop.
bus_volume_each_stop = bus_volume.groupby('ORIGIN_PT_CODE')['TOTAL_TRIPS'].sum().reset_index()
bus_volume_each_stop.rename(columns={'ORIGIN_PT_CODE': 'BusStopCode_x', 'TOTAL_TRIPS': 'TotalBusTrips'}, inplace=True)

bus_volume_each_stop

# %%
# Passenger Volume
# Group train_volume by the ORIGIN_PT_CODE and sum up to get the total number of trips for each train station.
train_volume_each_stn = train_volume.groupby('ORIGIN_PT_CODE')['TOTAL_TRIPS'].sum().reset_index()
train_volume_each_stn.rename(columns={'ORIGIN_PT_CODE': 'TrainStationCode', 'TOTAL_TRIPS': 'TotalTrainTrips'}, inplace=True)
train_volume_each_stn

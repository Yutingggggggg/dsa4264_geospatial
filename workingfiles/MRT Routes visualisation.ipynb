# %%
import requests
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, LineString
import folium
import time
import os
import re
from tqdm import tqdm
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None

# %%
import os
os.environ['OGR_GEOMETRY_ACCEPT_UNCLOSED_RING'] = 'NO'

train_stations = gpd.read_file("./RapidTransitSystemStation.shp")

train_stations_4326 = train_stations.to_crs(epsg = 4326)


train_stations_4326['geometry'] = train_stations_4326['geometry'].apply(
    lambda geom: geom.centroid if geom.geom_type in ['Polygon', 'MultiPolygon'] else geom
)

train_stations_4326
# Out:
#      TYP_CD STN_NAM ATTACHEMEN TYP_CD_DES                      STN_NAM_DE  \
# 0         0    None       None        MRT                 GALI BATU DEPOT
# 1         0    None       None        MRT            HILLVIEW MRT STATION
# 2         0    None       None        MRT        BEAUTY WORLD MRT STATION
# 3         0    None       None        MRT                HUME MRT STATION
# 4         0    None       None        MRT       BUKIT PANJANG MRT STATION
# ..      ...     ...        ...        ...                             ...
# 225       0    None       None        MRT         KATONG PARK MRT STATION
# 226       0    None       None        MRT      MARINE TERRACE MRT STATION
# 227       0    None       None        MRT         TANJONG RHU MRT STATION
# 228       0    None       None        MRT       MARINE PARADE MRT STATION
# 229       0    None       None        MRT  FOUNDERS' MEMORIAL MRT STATION
#
#                       geometry
# 0    POINT (103.75609 1.39759)
# 1    POINT (103.76743 1.36234)
# 2     POINT (103.77582 1.3412)
# 3     POINT (103.7691 1.35451)
# 4    POINT (103.76157 1.37916)
# ..                         ...
# 225  POINT (103.88618 1.29782)
# 226  POINT (103.91532 1.30679)
# 227  POINT (103.87345 1.29721)
# 228  POINT (103.90551 1.30287)
# 229  POINT (103.86892 1.29098)
#
# [230 rows x 6 columns]

# %%
train_stations_3857 = train_stations.to_crs(3857)

train_stations_3857["geometry"] = train_stations_3857["geometry"].centroid

train_stations_3857
# Out:
#      TYP_CD STN_NAM ATTACHEMEN TYP_CD_DES                      STN_NAM_DE  \
# 0         0    None       None        MRT                 GALI BATU DEPOT
# 1         0    None       None        MRT            HILLVIEW MRT STATION
# 2         0    None       None        MRT        BEAUTY WORLD MRT STATION
# 3         0    None       None        MRT                HUME MRT STATION
# 4         0    None       None        MRT       BUKIT PANJANG MRT STATION
# ..      ...     ...        ...        ...                             ...
# 225       0    None       None        MRT         KATONG PARK MRT STATION
# 226       0    None       None        MRT      MARINE TERRACE MRT STATION
# 227       0    None       None        MRT         TANJONG RHU MRT STATION
# 228       0    None       None        MRT       MARINE PARADE MRT STATION
# 229       0    None       None        MRT  FOUNDERS' MEMORIAL MRT STATION
#
#                             geometry
# 0    POINT (11550075.331 155593.891)
# 1    POINT (11551337.385 151669.297)
# 2    POINT (11552271.325 149315.735)
# 3    POINT (11551523.809 150797.503)
# 4    POINT (11550685.441 153542.239)
# ..                               ...
# 225  POINT (11564556.889 144485.295)
# 226  POINT (11567800.045 145483.386)
# 227  POINT (11563139.751 144417.599)
# 228  POINT (11566708.269 145046.784)
# 229   POINT (11562634.88 143723.287)
#
# [230 rows x 6 columns]

# %%
mrt_file_loc = "C:/Users/kaili/OneDrive/Documents/DSA4264/mrt_stations/mrt_stations.shp"
mrt_gdf = gpd.read_file(mrt_file_loc)

# %%
mrt_gdf["lat_lng"] = gpd.points_from_xy(mrt_gdf["LATITUDE"], mrt_gdf["LONGITUDE"])

mrt_gdf["line"] = mrt_gdf["CODE"].str.slice(0, 2) 

mrt_lines_code = ["NS", "EW", "CC", "NE", "TE", "DT"]

mrt_gdf_wo_lrt = mrt_gdf[mrt_gdf["line"].isin(mrt_lines_code)].reset_index()
mrt_gdf_wo_lrt = mrt_gdf_wo_lrt.drop("index", axis = 1)

mrt_gdf_wo_lrt["STN_NAM_DE"] = mrt_gdf_wo_lrt["BUILDING"].str.split('(').str[0].str.strip()

# %%
mrt_gdf_wo_lrt2 = mrt_gdf_wo_lrt[["CODE", "STN_NAM_DE", "LINE", "line", "COLOR"]]

mrt_gdf_wo_lrt2["Order"] = pd.to_numeric(mrt_gdf_wo_lrt2["CODE"].str.slice(2, None))

mrt_gdf_wo_lrt2[mrt_gdf_wo_lrt["line"] == "TE"].sort_values("Order", ascending = False)
# Out:
#      CODE                      STN_NAM_DE                     LINE line  \
# 157  TE22  GARDENS BY THE BAY MRT STATION  Thomson-East Coast Line   TE
# 156  TE20          MARINA BAY MRT STATION  Thomson-East Coast Line   TE
# 155  TE19         SHENTON WAY MRT STATION  Thomson-East Coast Line   TE
# 154  TE18             MAXWELL MRT STATION  Thomson-East Coast Line   TE
# 153  TE17         OUTRAM PARK MRT STATION  Thomson-East Coast Line   TE
# 152  TE16            HAVELOCK MRT STATION  Thomson-East Coast Line   TE
# 151  TE15         GREAT WORLD MRT STATION  Thomson-East Coast Line   TE
# 150  TE14             ORCHARD MRT STATION  Thomson-East Coast Line   TE
# 149  TE13   ORCHARD BOULEVARD MRT STATION  Thomson-East Coast Line   TE
# 148  TE12              NAPIER MRT STATION  Thomson-East Coast Line   TE
# 147  TE11             STEVENS MRT STATION  Thomson-East Coast Line   TE
# 146   TE9           CALDECOTT MRT STATION  Thomson-East Coast Line   TE
# 145   TE8       UPPER THOMSON MRT STATION  Thomson-East Coast Line   TE
# 144   TE7         BRIGHT HILL MRT STATION  Thomson-East Coast Line   TE
# 143   TE6           MAYFLOWER MRT STATION  Thomson-East Coast Line   TE
# 142   TE5              LENTOR MRT STATION  Thomson-East Coast Line   TE
# 141   TE4          SPRINGLEAF MRT STATION  Thomson-East Coast Line   TE
# 140   TE3     WOODLANDS SOUTH MRT STATION  Thomson-East Coast Line   TE
# 139   TE2           WOODLANDS MRT STATION  Thomson-East Coast Line   TE
# 138   TE1     WOODLANDS NORTH MRT STATION  Thomson-East Coast Line   TE
#
#      COLOR  Order
# 157  Brown     22
# 156  Brown     20
# 155  Brown     19
# 154  Brown     18
# 153  Brown     17
# 152  Brown     16
# 151  Brown     15
# 150  Brown     14
# 149  Brown     13
# 148  Brown     12
# 147  Brown     11
# 146  Brown      9
# 145  Brown      8
# 144  Brown      7
# 143  Brown      6
# 142  Brown      5
# 141  Brown      4
# 140  Brown      3
# 139  Brown      2
# 138  Brown      1

# %%
new_brown_line = ['TANJONG RHU MRT STATION','KATONG PARK MRT STATION', 'TANJONG KATONG MRT STATION', 
                  'MARINE PARADE MRT STATION', 'MARINE TERRACE MRT STATION', 'SIGLAP MRT STATION', 'BAYSHORE MRT STATION']

# %%
n = len(new_brown_line)
add_tel_stations = []
for i in range(n):
    no = i + 23
    station_name = new_brown_line[i]
    add_tel_stations.append({
        "CODE": "TE" + str(no),
        "STN_NAM_DE": station_name,
        "LINE": "Thomson-East Coast Line",
        "line": "TE",
        "COLOR": "Brown",
        "Order": no
    })

new_tel_stations = pd.DataFrame(add_tel_stations)

mrt_gdf_wo_lrt2 = pd.concat([mrt_gdf_wo_lrt2, new_tel_stations], axis = 0)
mrt_gdf_wo_lrt2
# Out:
#     CODE                  STN_NAM_DE                     LINE line  COLOR  \
# 0    NS1     JURONG EAST MRT STATION         North-South Line   NS    Red
# 1    NS2     BUKIT BATOK MRT STATION         North-South Line   NS    Red
# 2    NS3    BUKIT GOMBAK MRT STATION         North-South Line   NS    Red
# 3    NS4   CHOA CHU KANG MRT STATION         North-South Line   NS    Red
# 4    NS5         YEW TEE MRT STATION         North-South Line   NS    Red
# ..   ...                         ...                      ...  ...    ...
# 2   TE25  TANJONG KATONG MRT STATION  Thomson-East Coast Line   TE  Brown
# 3   TE26   MARINE PARADE MRT STATION  Thomson-East Coast Line   TE  Brown
# 4   TE27  MARINE TERRACE MRT STATION  Thomson-East Coast Line   TE  Brown
# 5   TE28          SIGLAP MRT STATION  Thomson-East Coast Line   TE  Brown
# 6   TE29        BAYSHORE MRT STATION  Thomson-East Coast Line   TE  Brown
#
#     Order
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
# ..    ...
# 2      25
# 3      26
# 4      27
# 5      28
# 6      29
#
# [165 rows x 6 columns]

# %%
mrt_stations_3857 = mrt_gdf_wo_lrt2.merge(train_stations_3857, how = "left", on = "STN_NAM_DE")
mrt_stations_4326 = mrt_gdf_wo_lrt2.merge(train_stations_4326, how = "left", on = "STN_NAM_DE")

mrt_stations_4326
# Out:
#      CODE                  STN_NAM_DE                     LINE line  COLOR  \
# 0     NS1     JURONG EAST MRT STATION         North-South Line   NS    Red
# 1     NS2     BUKIT BATOK MRT STATION         North-South Line   NS    Red
# 2     NS3    BUKIT GOMBAK MRT STATION         North-South Line   NS    Red
# 3     NS4   CHOA CHU KANG MRT STATION         North-South Line   NS    Red
# 4     NS5         YEW TEE MRT STATION         North-South Line   NS    Red
# ..    ...                         ...                      ...  ...    ...
# 215  TE26   MARINE PARADE MRT STATION  Thomson-East Coast Line   TE  Brown
# 216  TE27  MARINE TERRACE MRT STATION  Thomson-East Coast Line   TE  Brown
# 217  TE28          SIGLAP MRT STATION  Thomson-East Coast Line   TE  Brown
# 218  TE29        BAYSHORE MRT STATION  Thomson-East Coast Line   TE  Brown
# 219  TE29        BAYSHORE MRT STATION  Thomson-East Coast Line   TE  Brown
#
#      Order  TYP_CD STN_NAM ATTACHEMEN TYP_CD_DES                   geometry
# 0        1       0    None       None        MRT  POINT (103.74226 1.33321)
# 1        2       0    None       None        MRT    POINT (103.74954 1.349)
# 2        3       0    None       None        MRT  POINT (103.75191 1.35867)
# 3        4       0    None       None        MRT  POINT (103.74437 1.38517)
# 4        5       0    None       None        MRT   POINT (103.7474 1.39755)
# ..     ...     ...     ...        ...        ...                        ...
# 215     26       0    None       None        MRT  POINT (103.90551 1.30287)
# 216     27       0    None       None        MRT  POINT (103.91532 1.30679)
# 217     28       0    None       None        MRT  POINT (103.92988 1.30988)
# 218     29       0    None       None        MRT  POINT (103.94344 1.31348)
# 219     29       0    None       None        MRT   POINT (103.9416 1.31284)
#
# [220 rows x 11 columns]

# %%
# Group by 'grouper' and create LineString geometries
def create_linestring(group):
    # Check if there are at least two points to create a LineString
    if len(group) > 1:
        return LineString(group.to_list())
    else:
        # Return the original geometry if not enough points for a LineString
        return group.iloc[0]

# Apply the function to create LineString geometries
test_df_3857 = mrt_stations_3857.groupby(["line", "COLOR"])["geometry"].apply(create_linestring)

# Convert the resulting Series to a GeoDataFrame
geo_df_3857 = gpd.GeoDataFrame(test_df_3857, geometry="geometry").reset_index()

lines_gdf_3857 = geo_df_3857[geo_df_3857.geometry.type == "LineString"]
lines_gdf_3857 = lines_gdf_3857.reset_index()
lines_gdf_3857
# Out:
#    index line   COLOR                                           geometry
# 0      0   CC  Orange  LINESTRING (11560065.268 144621.33, 11560096.7...
# 1      1   DT    Blue  LINESTRING (11550685.441 153542.239, 11551033....
# 2      2   EW   Green  LINESTRING (11571578.429 152850.932, 11571122....
# 3      3   NE  Purple  LINESTRING (11557351.029 140881.522, 11557363....
# 4      4   NS     Red  LINESTRING (11548535.917 148425.544, 11549346....
# 5      5   TE   Brown  LINESTRING (11553368.462 161246.769, 11553422....

# %%
# Apply the function to create LineString geometries
test_df_4326 = mrt_stations_4326.groupby(["line", "COLOR"])["geometry"].apply(create_linestring)

# Convert the resulting Series to a GeoDataFrame
geo_df_4326 = gpd.GeoDataFrame(test_df_4326, geometry="geometry").reset_index()

lines_gdf_4326 = geo_df_4326[geo_df_4326.geometry.type == "LineString"]
lines_gdf_4326 = lines_gdf_4326.reset_index()
lines_gdf_4326
# Out:
#    index line   COLOR                                           geometry
# 0      0   CC  Orange  LINESTRING (103.84583 1.29904, 103.84612 1.298...
# 1      1   DT    Blue  LINESTRING (103.76157 1.37916, 103.7647 1.3693...
# 2      2   EW   Green  LINESTRING (103.94926 1.37295, 103.94516 1.353...
# 3      3   NE  Purple  LINESTRING (103.82145 1.26546, 103.82157 1.265...
# 4      4   NS     Red  LINESTRING (103.74226 1.33321, 103.74954 1.349...
# 5      5   TE   Brown  LINESTRING (103.78567 1.44835, 103.78616 1.436...

# %%
color_dict = {
    "Red": "#c03731",
    "Green": "#1f844d",
    "Purple": "#953aa6",
    "Orange": "#fba01d",
    "Blue": "#134f9a",
    "Brown": "#9d6633"
}

# %%
train_stations_4326.loc[166].geometry.is_empty
# Out:
# True

# %%
m = folium.Map(location=[1.3521, 103.8198], zoom_start=12)

for index, row in lines_gdf_4326.iterrows():
    color = color_dict[row['COLOR']]
    locations = [(coord[1], coord[0]) for coord in row["geometry"].coords]
    folium.PolyLine(
        locations=locations,
        color=color,
        weight=2,
    ).add_to(m)


for index, row in mrt_stations_4326.iterrows():
    color = color_dict[row["COLOR"]]
    tooltip = f"""
    <div style="color: white; background-color: {color}; padding: 5px; border-radius: 5px;">
        <b>{row['CODE']}: {row['STN_NAM_DE']} {'MRT'} Station</b>
    </div>
    """
    radius=3
    folium.CircleMarker(
        location=[row.geometry.y, row.geometry.x],
        radius=radius,
        weight=0.5,
        color=color,
        fill_color=color,
        fill_opacity=1,
        tooltip=tooltip,
    ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99a59e1b63853328dd03f602e39e570d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99a59e1b63853328dd03f602e39e570d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99a59e1b63853328dd03f602e39e570d = L.map(
#                 &quot;map_99a59e1b63853328dd03f602e39e570d&quot;,
#                 {
#                     center: [1.3521, 103.8198],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_748f736b27d45e7c235b1aac6dc9ff43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_748f736b27d45e7c235b1aac6dc9ff43.addTo(map_99a59e1b63853328dd03f602e39e570d);
#
#
#             var poly_line_bcfbe28163e3522e7ade6d4aef1b4d5f = L.polyline(
#                 [[1.2990442028345541, 103.84583316085424], [1.2986992881274089, 103.84611560154931], [1.2997033927844648, 103.84548639483836], [1.2968267736812158, 103.85065551110229], [1.2932599003510712, 103.85561173032032], [1.2932501663358644, 103.86099644320825], [1.2927982014673371, 103.86086463574634], [1.2998028298586857, 103.86363313786222], [1.3028540997957776, 103.87534796366792], [1.306193786906133, 103.88254701504097], [1.3083751546498659, 103.88866829958701], [1.3173694011754167, 103.89227219436665], [1.3181133870326036, 103.89304886915033], [1.3263680370907769, 103.89026149704654], [1.3260906192664055, 103.88937168274663], [1.3354531035110178, 103.88816447567163], [1.3428468439785775, 103.87972518715094], [1.3505310710711225, 103.87246307182336], [1.3496172241812994, 103.87363463482828], [1.3516197558519703, 103.86414412649162], [1.3512585800526482, 103.84922134147403], [1.350838384957845, 103.84814352682146], [1.3487766563073866, 103.83941284508413], [1.337658547487041, 103.83954121423216], [1.3373172464803227, 103.84013848431175], [1.322109492289093, 103.81498942395852], [1.322401507309043, 103.8161588884189], [1.317454570813084, 103.80748912454449], [1.3119456175562414, 103.79623333605994], [1.3072583223172616, 103.78994227911473], [1.3064837022792515, 103.79063266054504], [1.2996564796341612, 103.78739399259958], [1.2934009385686591, 103.78449793820667], [1.2825029023010162, 103.78182132859038], [1.2762296702461609, 103.79134196567098], [1.2723234939741757, 103.802927704994], [1.2705817862734652, 103.809739755979], [1.2654573481966436, 103.82145073490719], [1.265164170822103, 103.8215664337839]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fba01d&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#fba01d&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_99a59e1b63853328dd03f602e39e570d);
#
#
#             var poly_line_4100b4a4115f9a2662dc1422870618cf = L.polyline(
#                 [[1.3791601965430647, 103.7615727407132], [1.369361584589663, 103.7646971904582], [1.362340089593893, 103.76742925204972], [1.3412035628578338, 103.7758189768096], [1.3356381112569964, 103.78387153204426], [1.3307848577029833, 103.79732046034653], [1.3258706042449908, 103.80733086505684], [1.322109492289093, 103.81498942395852], [1.322401507309043, 103.8161588884189], [1.3200659544278468, 103.82602302612514], [1.3193857429457014, 103.82556219138687], [1.3123222844220106, 103.83798766444971], [1.3135013088925045, 103.83808187977135], [1.3071673591876494, 103.84861049938442], [1.3071554948824642, 103.84984510832265], [1.3039275602387224, 103.85243888564267], [1.30062682083703, 103.8558393480689], [1.299450665376452, 103.85688639247027], [1.2932501663358644, 103.86099644320825], [1.2927982014673371, 103.86086463574634], [1.2818719115166022, 103.859076454252], [1.2794414873386641, 103.85285112551882], [1.2822805842933016, 103.84831284849372], [1.2843575513488368, 103.84347988616315], [1.2846275212729499, 103.84455749337168], [1.2924715941627751, 103.84432545090245], [1.2987271895030152, 103.8502448898811], [1.3053804826385775, 103.855435040457], [1.3136449960335717, 103.86289119759553], [1.3215128865409695, 103.87191146420642], [1.326865682235178, 103.88325305974074], [1.3263680370907769, 103.89026149704654], [1.3260906192664055, 103.88937168274663], [1.329955264485581, 103.89924886682206], [1.3349629786569683, 103.90845515789609], [1.3347556340969402, 103.91787672257556], [1.3365987355856837, 103.93228754718295], [1.3455175071527512, 103.93842947022262], [1.3532891914048886, 103.94515900769592], [1.3551430033191982, 103.94301596859795], [1.3562130022416439, 103.95480497223646], [1.3417404787997753, 103.96147329733266], [1.33525210793

# %%
mrt_stations_4326[mrt_stations_4326["STN_NAM_DE"] == "HILLVIEW MRT STATION"]
# Out:
#     CODE            STN_NAM_DE           LINE line COLOR  Order  TYP_CD  \
# 140  DT3  HILLVIEW MRT STATION  Downtown Line   DT  Blue      3       0
#
#     STN_NAM ATTACHEMEN TYP_CD_DES                   geometry
# 140    None       None        MRT  POINT (103.76743 1.36234)

# %%
train_stations_4326.head()
# Out:
#    TYP_CD STN_NAM ATTACHEMEN TYP_CD_DES                 STN_NAM_DE  \
# 0       0    None       None        MRT            GALI BATU DEPOT
# 1       0    None       None        MRT       HILLVIEW MRT STATION
# 2       0    None       None        MRT   BEAUTY WORLD MRT STATION
# 3       0    None       None        MRT           HUME MRT STATION
# 4       0    None       None        MRT  BUKIT PANJANG MRT STATION
#
#                     geometry
# 0  POINT (103.75609 1.39759)
# 1  POINT (103.76743 1.36234)
# 2   POINT (103.77582 1.3412)
# 3   POINT (103.7691 1.35451)
# 4  POINT (103.76157 1.37916)

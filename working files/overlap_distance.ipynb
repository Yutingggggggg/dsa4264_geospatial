# %%
# %run data.ipynb
# Out:
# ['https://ltafarecard.s3.ap-southeast-1.amazonaws.com/202409/origin_destination_bus_202409.zip?X-Amz-Security-Token=IQoJb3JpZ2luX2VjELf%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDmFwLXNvdXRoZWFzdC0xIkcwRQIgMnCbS8ESvu6WMXB7ieh%2FItNqV%2BKV0K9n26%2BGC0Tn2eECIQCykfGvVMnTlhqTRwr%2FYYTTg%2F8uabshmCnO%2FbatgSGg1yrCBQgwEAQaDDM0MDY0NTM4MTMwNCIMdZ4YGUn6aCa4X%2BI9Kp8Ftavp1LFin0I%2B78a66RRMyZIJKm8YMAJer2459fVUIuw1US4nOvEDfAJHfh3Efjnp%2FVZbpr4TWGCZFaiXFEwoAGreXRC6vVrujhj7MxtDklsEBvfeJFGiX5p1Sgv64ayoLf26AsnxGwFRuiWdUOBMz1Sm04rvHtsVD0rjnCBRX%2Fti1ci2fQDR7MDPkVenMCE8tXBuqeJIR7KQr2st4%2B1zjBK3rcYewXj%2BRcegC387ej690cgnJSpU6j5g6wR48%2B2wiWtLO9%2FARRsPGWRekR0VA%2FMfwyhx%2FHFTlHinfdsQdpswKxaoqIA%2FXv5tYortbhdoaZy5K5%2FGnHKcZe18UvajXk9YUAwVHAQzVyyjswL6BuMqp5vCc4qwTPnLUDPpwmQR0Zt%2BYSbbO%2BU0jNyOesCvYoCNTjdxEOsHU5xfRH9OK9mdbptNa9cnuVNPkc17kbXdt85qjiTk13WBlLTo5NUDvgX5vvmtxRFPCfuqgq6mPVFlWZjYvGI8Qybz4iTSDF4bU3liHgyf9CEqSpifcB7E7abJuzFTrANWr8aYPp5lEVzH3GsvyiVXOuDiAFApObW1RDwf90N4Ydyeobz4SZ%2BAlf3I4kGORALr5PGZIJAy2WMvUZFE4BNfinydl6k2MQSTPRvqyLrJv1KGvVQaMXWsPDyyPAmr07t2sPai2UZuFLZmyADxcIj1vpYFlt7ZzDrMYCMs3SF3xJCDZ1DUNy4Lu83wdwE8m06SDY%2BZTe6acMU%2B1JCU600rmkg%2B%2Flp%2FhjUIvSbR27dPST505byfn28LZr1WPQt8sH8wWT1ieObH3QilbCza5h3n2uKF4B5hkyeM3LMrP4VI024Q1ca%2Be0Vh1as%2FJ6UAG71fqdFgaJxMSCOtPDGEmDQeTFgeIxnJn1Iw%2FLH5uAY6sQHmwUrkkNhSEY%2BwazrMQLafFNOmKMvDvRYRpDTXV1IArnWTrSQkZionc1nDQSDialMT4%2FhjWTfPOkgsbySReRXStMxURI8vj9Qf5GeAt3SbGgK4iLqrLZQODSTKlxlu0UdvUW0it%2B8fhiIN98RaxBnAjiFNLXUxOu%2BJ7%2BwInUwEpmLKb5PUXXgfgmaYnk6L0f9z1F%2BV5ajn6zCqVeEAMHdiR5KkYn03ddu4TenBzzMrPXk%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20241027T165207Z&X-Amz-SignedHeaders=host&X-Amz-Expires=299&X-Amz-Credential=ASIAU6UAMAS4LL7OUQFE%2F20241027%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=a2a6506f28ba75d308e6893bcdb193a35219cc2583091b1cb105ee1b6e6ebec5']
# ['https://ltafarecard.s3.ap-southeast-1.amazonaws.com/202409/origin_destination_train_202409.zip?X-Amz-Security-Token=IQoJb3JpZ2luX2VjELf%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDmFwLXNvdXRoZWFzdC0xIkYwRAIgE7nHLOdGfVPOXL%2BmWunzSL%2FnUHQJvnvCHqlBrSONgAgCIEMOEAl1V1x2mhx2rfnLJzZ3%2BaPwifoAiwwEtrQNSkZWKsIFCDAQBBoMMzQwNjQ1MzgxMzA0Igy9F8ieyktiYdXRJcUqnwUiTQqefnYozKZO7WS1%2FjBNzZvbBKz0GXuWCqvO5vgT5uuBBE7RMJeSU9GLfjLZrmeK9LtAgovE9YNGGpTZXrHxxBGf7wvFA18leEg2ICXT4JGz%2B03KL65YTbePbytE6iPhih16IFuJ%2BM5EEztD6AykPX%2Bn5Riv4q3Qw3D2ZP7q8tOZLelVPG%2BSyAR6BttnYWyqLQkDAfSpTiDeUnJJHAWXXj6nXUk3%2B8V9%2BPBf7%2FvHeqmipsSKhF0tUv32VPWotocKbaK71Bc%2BEjVsch8eDgqdnBMhCHKqSUjKACEVeHSuCsmcjAPpRZ1Chn75j3eOgSKnSGW6tgHwQSkQ%2F1FUr2HkURaqP8nJow0vhmRi09D4FnnustAOlgFD8EhoMNIbW7l6ApZtS0e3K6ItHbEDo0Z5BIsUlB9ZXGOO768a4mVa6pXCYuehv%2BlciKX4ALfQpk%2B7UBKQhLO3Kl3MRyetA2aklhWRG7p0ySSGEUYSBeuygiErsfh8x2uDXXIUVpM1NePAYP%2FgjdaTwgWYJNmBCD6BpUmG0GWV0P7XsKA4f7Uuk2pE1WQl6FZ8Rf9U6EknBQrSNbKIv1kqeJ22qY3p3OCagvghv5yBVyBM8khg%2FTPTkZ%2FY3xfqXqwngzrnxmQgAVLr%2Fqb0DE1jYWhR6noGfry7AZgNKp%2F4XpkC4VobAAAU1jPoCALEUrXn8ErpWMO6Gtla19XT7M1T%2F1atdl%2FETXtCJa0cwg24LuUf5EiSL7XhjKy2aDMYblJUIypDc9IFS923m7jKI7vzkdq2Wwzc2vn25cVdtcevBkrSoRvm1nPzOUnAMbyLJBiQXWX8cA%2FCebVFnJAjGrbvVSImsTj621qtV9zVnkK5npfCH%2BfY2Wc2Un5LbBSy%2B5SvLnFfPrl5hjDOs%2Fm4BjqyAfuJ57CfT%2B23%2BnCxpIlPCbDUXaNlS50bX00ciZZza3iVpV0FWydWnGNlI8PTaL29h2qGpXh2sG%2BurPR8PFworNPYmnUKu55stjM4Wij3%2BcsdHwGols%2B7r0rmMRPlVDd%2BgQEPMgI0AyHLAst86vL4vb2%2ByxCN6NboO9zOUKiRvCr%2FdNFnK8ifTc2zgfmuED4ZNsHQ5R5F%2BSi0Fpn7OInYrD5jUkmPjCXoLdqWgHNepjSOD8E%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20241027T165211Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAU6UAMAS4EPH226VD%2F20241027%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=167a4a06544f789d0a56628645262df51af4b91813cb812360cad9795aeadfda']

# %%
# %run nearest_mrt_station_to_bus_stops.ipynb
# Out:
# ['https://ltafarecard.s3.ap-southeast-1.amazonaws.com/202409/origin_destination_bus_202409.zip?X-Amz-Security-Token=IQoJb3JpZ2luX2VjELf%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDmFwLXNvdXRoZWFzdC0xIkcwRQIgMnCbS8ESvu6WMXB7ieh%2FItNqV%2BKV0K9n26%2BGC0Tn2eECIQCykfGvVMnTlhqTRwr%2FYYTTg%2F8uabshmCnO%2FbatgSGg1yrCBQgwEAQaDDM0MDY0NTM4MTMwNCIMdZ4YGUn6aCa4X%2BI9Kp8Ftavp1LFin0I%2B78a66RRMyZIJKm8YMAJer2459fVUIuw1US4nOvEDfAJHfh3Efjnp%2FVZbpr4TWGCZFaiXFEwoAGreXRC6vVrujhj7MxtDklsEBvfeJFGiX5p1Sgv64ayoLf26AsnxGwFRuiWdUOBMz1Sm04rvHtsVD0rjnCBRX%2Fti1ci2fQDR7MDPkVenMCE8tXBuqeJIR7KQr2st4%2B1zjBK3rcYewXj%2BRcegC387ej690cgnJSpU6j5g6wR48%2B2wiWtLO9%2FARRsPGWRekR0VA%2FMfwyhx%2FHFTlHinfdsQdpswKxaoqIA%2FXv5tYortbhdoaZy5K5%2FGnHKcZe18UvajXk9YUAwVHAQzVyyjswL6BuMqp5vCc4qwTPnLUDPpwmQR0Zt%2BYSbbO%2BU0jNyOesCvYoCNTjdxEOsHU5xfRH9OK9mdbptNa9cnuVNPkc17kbXdt85qjiTk13WBlLTo5NUDvgX5vvmtxRFPCfuqgq6mPVFlWZjYvGI8Qybz4iTSDF4bU3liHgyf9CEqSpifcB7E7abJuzFTrANWr8aYPp5lEVzH3GsvyiVXOuDiAFApObW1RDwf90N4Ydyeobz4SZ%2BAlf3I4kGORALr5PGZIJAy2WMvUZFE4BNfinydl6k2MQSTPRvqyLrJv1KGvVQaMXWsPDyyPAmr07t2sPai2UZuFLZmyADxcIj1vpYFlt7ZzDrMYCMs3SF3xJCDZ1DUNy4Lu83wdwE8m06SDY%2BZTe6acMU%2B1JCU600rmkg%2B%2Flp%2FhjUIvSbR27dPST505byfn28LZr1WPQt8sH8wWT1ieObH3QilbCza5h3n2uKF4B5hkyeM3LMrP4VI024Q1ca%2Be0Vh1as%2FJ6UAG71fqdFgaJxMSCOtPDGEmDQeTFgeIxnJn1Iw%2FLH5uAY6sQHmwUrkkNhSEY%2BwazrMQLafFNOmKMvDvRYRpDTXV1IArnWTrSQkZionc1nDQSDialMT4%2FhjWTfPOkgsbySReRXStMxURI8vj9Qf5GeAt3SbGgK4iLqrLZQODSTKlxlu0UdvUW0it%2B8fhiIN98RaxBnAjiFNLXUxOu%2BJ7%2BwInUwEpmLKb5PUXXgfgmaYnk6L0f9z1F%2BV5ajn6zCqVeEAMHdiR5KkYn03ddu4TenBzzMrPXk%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20241027T165221Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAU6UAMAS4LL7OUQFE%2F20241027%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=2e060c575fc0e506151b9c2ba3a9d4e3f5f6ea47388953629e8344cdb7996329']
# ['https://ltafarecard.s3.ap-southeast-1.amazonaws.com/202409/origin_destination_train_202409.zip?X-Amz-Security-Token=IQoJb3JpZ2luX2VjELf%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDmFwLXNvdXRoZWFzdC0xIkcwRQIgMnCbS8ESvu6WMXB7ieh%2FItNqV%2BKV0K9n26%2BGC0Tn2eECIQCykfGvVMnTlhqTRwr%2FYYTTg%2F8uabshmCnO%2FbatgSGg1yrCBQgwEAQaDDM0MDY0NTM4MTMwNCIMdZ4YGUn6aCa4X%2BI9Kp8Ftavp1LFin0I%2B78a66RRMyZIJKm8YMAJer2459fVUIuw1US4nOvEDfAJHfh3Efjnp%2FVZbpr4TWGCZFaiXFEwoAGreXRC6vVrujhj7MxtDklsEBvfeJFGiX5p1Sgv64ayoLf26AsnxGwFRuiWdUOBMz1Sm04rvHtsVD0rjnCBRX%2Fti1ci2fQDR7MDPkVenMCE8tXBuqeJIR7KQr2st4%2B1zjBK3rcYewXj%2BRcegC387ej690cgnJSpU6j5g6wR48%2B2wiWtLO9%2FARRsPGWRekR0VA%2FMfwyhx%2FHFTlHinfdsQdpswKxaoqIA%2FXv5tYortbhdoaZy5K5%2FGnHKcZe18UvajXk9YUAwVHAQzVyyjswL6BuMqp5vCc4qwTPnLUDPpwmQR0Zt%2BYSbbO%2BU0jNyOesCvYoCNTjdxEOsHU5xfRH9OK9mdbptNa9cnuVNPkc17kbXdt85qjiTk13WBlLTo5NUDvgX5vvmtxRFPCfuqgq6mPVFlWZjYvGI8Qybz4iTSDF4bU3liHgyf9CEqSpifcB7E7abJuzFTrANWr8aYPp5lEVzH3GsvyiVXOuDiAFApObW1RDwf90N4Ydyeobz4SZ%2BAlf3I4kGORALr5PGZIJAy2WMvUZFE4BNfinydl6k2MQSTPRvqyLrJv1KGvVQaMXWsPDyyPAmr07t2sPai2UZuFLZmyADxcIj1vpYFlt7ZzDrMYCMs3SF3xJCDZ1DUNy4Lu83wdwE8m06SDY%2BZTe6acMU%2B1JCU600rmkg%2B%2Flp%2FhjUIvSbR27dPST505byfn28LZr1WPQt8sH8wWT1ieObH3QilbCza5h3n2uKF4B5hkyeM3LMrP4VI024Q1ca%2Be0Vh1as%2FJ6UAG71fqdFgaJxMSCOtPDGEmDQeTFgeIxnJn1Iw%2FLH5uAY6sQHmwUrkkNhSEY%2BwazrMQLafFNOmKMvDvRYRpDTXV1IArnWTrSQkZionc1nDQSDialMT4%2FhjWTfPOkgsbySReRXStMxURI8vj9Qf5GeAt3SbGgK4iLqrLZQODSTKlxlu0UdvUW0it%2B8fhiIN98RaxBnAjiFNLXUxOu%2BJ7%2BwInUwEpmLKb5PUXXgfgmaYnk6L0f9z1F%2BV5ajn6zCqVeEAMHdiR5KkYn03ddu4TenBzzMrPXk%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20241027T165224Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAU6UAMAS4LL7OUQFE%2F20241027%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=41c4b1a168e12b8f5fbf4b9b403704af5187ed3e9c40169531ff3778b4757f4a']
# 25548it [00:09, 2620.04it/s]

# %%
# mrt stations geodataframe
import os
os.environ['OGR_GEOMETRY_ACCEPT_UNCLOSED_RING'] = 'NO'

mrt_stations_gdf = geopandas.read_file('./TrainStation_Jul2024/RapidTransitSystemStation.shp')
mrt_stations_gdf_3857 = mrt_stations_gdf.to_crs(3857)
mrt_stations_gdf_3857
# Out:
#      TYP_CD STN_NAM ATTACHEMEN TYP_CD_DES                      STN_NAM_DE  \
# 0         0    None       None        MRT                 GALI BATU DEPOT
# 1         0    None       None        MRT            HILLVIEW MRT STATION
# 2         0    None       None        MRT        BEAUTY WORLD MRT STATION
# 3         0    None       None        MRT                HUME MRT STATION
# 4         0    None       None        MRT       BUKIT PANJANG MRT STATION
# ..      ...     ...        ...        ...                             ...
# 225       0    None       None        MRT         KATONG PARK MRT STATION
# 226       0    None       None        MRT      MARINE TERRACE MRT STATION
# 227       0    None       None        MRT         TANJONG RHU MRT STATION
# 228       0    None       None        MRT       MARINE PARADE MRT STATION
# 229       0    None       None        MRT  FOUNDERS' MEMORIAL MRT STATION
#
#                                               geometry
# 0    POLYGON ((11549880.181 155286.262, 11549893.09...
# 1    POLYGON ((11551320.421 151685.479, 11551324.86...
# 2    POLYGON ((11552265.127 149269.279, 11552255.26...
# 3    POLYGON ((11551478.151 150855.083, 11551485.53...
# 4    POLYGON ((11550666.118 153603.709, 11550698.62...
# ..                                                 ...
# 225  POLYGON ((11564432.509 144548.028, 11564447.75...
# 226  POLYGON ((11567908.523 145472.086, 11567908.42...
# 227  POLYGON ((11563110.672 144334.178, 11563108.03...
# 228  POLYGON ((11566600.443 144955.407, 11566582.69...
# 229  POLYGON ((11562591.609 143792.727, 11562595.94...
#
# [230 rows x 6 columns]

# %% [markdown]
# # Brown Line

# %%
brown_line = ['WOODLANDS NORTH MRT STATION', 'WOODLANDS MRT STATION', 'WOODLANDS SOUTH MRT STATION',
              'SPRINGLEAF MRT STATION', 'LENTOR MRT STATION', 'MAYFLOWER MRT STATION',
              'BRIGHT HILL MRT STATION', 'UPPER THOMSON MRT STATION', 'CALDECOTT MRT STATION',
              'STEVENS MRT STATION', 'NAPIER MRT STATION', 'ORCHARD BOULEVARD MRT STATION',
              'ORCHARD MRT STATION', 'GREAT WORLD MRT STATION', 'HAVELOCK MRT STATION',
              'OUTRAM PARK MRT STATION', 'MAXWELL MRT STATION', 'SHENTON WAY MRT STATION',
              'MARINA BAY MRT STATION', 'GARDENS BY THE BAY MRT STATION', 'TANJONG RHU MRT STATION',
              'KATONG PARK MRT STATION', 'TANJONG KATONG MRT STATION', 'MARINE PARADE MRT STATION',
              'MARINE TERRACE MRT STATION', 'SIGLAP MRT STATION', 'BAYSHORE MRT STATION',
              'BEDOK SOUTH MRT STATION', 'SUNGEI BEDOK MRT STATION']

# filter brown line stations from mrt stations geodataframe
brown_line_stations_gdf = mrt_stations_gdf_3857[mrt_stations_gdf_3857['STN_NAM_DE'].isin(brown_line)]

# order brown line stations based on list
brown_line_stations_gdf['STN_NAM_DE'] = pd.Categorical(brown_line_stations_gdf['STN_NAM_DE'],
                                                       categories = brown_line,
                                                       ordered = True)
brown_line_stations_gdf = brown_line_stations_gdf.sort_values('STN_NAM_DE')
brown_line_stations_gdf
# Out:
#      TYP_CD STN_NAM                    ATTACHEMEN TYP_CD_DES  \
# 192       0    None                          None        MRT
# 196       0    None                          None        MRT
# 177       0    None                          None        MRT
# 191       0    None                          None        MRT
# 187       0    None                          None        MRT
# 110       0    None                          None        MRT
# 219       0    None                          None        MRT
# 186       0    None                          None        MRT
# 217       0    None                          None        MRT
# 218       0    None                          None        MRT
# 109       0    None              CC17_CDT STN.zip        MRT
# 32        0    None                          None        MRT
# 203       0    None                          None        MRT
# 204       0    None                          None        MRT
# 212       0    None                          None        MRT
# 213       0    None                          None        MRT
# 104       0    None                          None        MRT
# 209       0    None                          None        MRT
# 202       0    None                          None        MRT
# 201       0    None                          None        MRT
# 84        0    None  C109_S_OTP_MAIN_A_R19_P2.zip        MRT
# 117       0    None               NE3_OTP STN.zip        MRT
# 210       0    None                          None        MRT
# 206       0    None                          None        MRT
# 64        0    None               CE2_MRB STN.zip        MRT
# 200       0    None                          None        MRT
# 115       0    None                          None        MRT
# 211       0    None                          None        MRT
# 208       0    None                          None        MRT
# 227       0    None                          None        MRT
# 225       0    None                          None        MRT
# 224       0    None                          None        MRT
# 222       0    None                          None        MRT
# 228       0    None                          None        MRT
# 226       0    None                          None        MRT
# 220       0    None                          None        MRT
# 221       0    None                          None        MRT
# 223       0    None                          None        MRT
#
#                          STN_NAM_DE  \
# 192     WOODLANDS NORTH MRT STATION
# 196           WOODLANDS MRT STATION
# 177           WOODLANDS MRT STATION
# 191     WOODLANDS SOUTH MRT STATION
# 187          SPRINGLEAF MRT STATION
# 110              LENTOR MRT STATION
# 219           MAYFLOWER MRT STATION
# 186         BRIGHT HILL MRT STATION
# 217       UPPER THOMSON MRT STATION
# 218           CALDECOTT MRT STATION
# 109           CALDECOTT MRT STATION
# 32              STEVENS MRT STATION
# 203             STEVENS MRT STATION
# 204              NAPIER MRT STATION
# 212   ORCHARD BOULEVARD MRT STATION
# 213             ORCHARD MRT STATION
# 104             ORCHARD MRT STATION
# 209         GREAT WORLD MRT STATION
# 202            HAVELOCK MRT STATION
# 201         OUTRAM PARK MRT STATION
# 84          OUTRAM PARK MRT STATION
# 117         OUTRAM PARK MRT STATION
# 210             MAXWELL MRT STATION
# 206         SHENTON WAY MRT STATION
# 64           MARINA BAY MRT STATION
# 200          MARINA BAY MRT STATION
# 115          MARINA BAY MRT STATION
# 211          MARINA BAY MRT STATION
# 208  GARDENS BY THE BAY MRT STATION
# 227         TANJONG RHU MRT STATION
# 225         KATONG PARK MRT STATION
# 224      TANJONG KATONG MRT STATION
# 222       MARINE PARADE MRT STATION
# 228       MARINE PARADE MRT STATION
# 226      MARINE TERRACE MRT STATION
# 220              SIGLAP MRT STATION
# 221            BAYSHORE MRT STATION
# 223            BAYSHORE MRT STATION
#
#                                               geometry
# 192  POLYGON ((11553290.504 161340.499, 11553308.78...
# 196  POLYGON ((11553655.571 159844.445, 11553714.07...
# 177  POLYGON ((11553305.733 159892.909, 11553302.44...
# 191  POLYGON ((11554340.403 158819.168, 11554344.10...
# 187  POLYGON ((11556983.209 155700.488, 11556972.59...
# 110  POLYGON ((11559127.808 154037.405, 11559127.68...
# 219  POLYGON ((11559099.098 152920.462, 11559094.58...
# 186  POLYGON ((11558731.827 151811.306, 11558686.82...
# 217  POLYGON ((11558480.214 150916.092, 11558483.67...
# 218  POLYGON ((11559462.068 148993.215, 11559463.61...
# 109  POLYGON ((11559344.392 148875.759, 11559342.18...
# 32   POLYGON ((11557812.324 147000.057, 11557816.70...
# 203  POLYGON ((11557783.878 146982.248, 11557809.15...
# 204  POLYGON ((11557084.982 145522.798, 11557083.15...
# 212  POLYGON ((11557609.258 145103.847, 11557596.44...
# 213  POLYGON ((11558441.87 145091.118, 11558443.047...
# 104  POLYGON ((11558548.169 145071.964, 11558537.94...
# 209  POLYGON ((11558678.291 144289.546, 11558665.64...
# 202  POLYGON ((11558703.693 143659.583, 11558718.50...
# 201  POLYGON ((11559308.372 142682.402, 11559298.43...
# 84   POLYGON ((11559237.753 142695.209, 11559251.83...
# 117  POLYGON ((11559350.232 142623.057, 11559353.15...
# 210  POLYGON ((11559913.945 142605.655, 11559959.79...
# 206  POLYGON ((11560637.091 142232.533, 11560638.12...
# 64   POLYGON ((11561070.528 141987.904, 11561054.72...
# 200  POLYGON ((11561017.163 142126.143, 11561004.19...
# 115  POLYGON ((11561039.437 141991.719, 11561036.58...
# 211  POLYGON ((11561104.449 141953.568, 11561129.46...
# 208  POLYGON ((11562517.349 142416.142, 11562517.16...
# 227  POLYGON ((11563110.672 144334.178, 11563108.03...
# 225  POLYGON ((11564432.509 144548.028, 11564447.75...
# 224  POLYGON ((11565796.023 144618.481, 11565798.11...
# 222  POLYGON ((11566865.98 145173.875, 11566857.526...
# 228  POLYGON ((11566600.443 144955.407, 11566582.69...
# 226  POLYGON ((11567908.523 145472.086, 11567908.42...
# 220  POLYGON ((11569421.424 145813.022, 11569353.34...
# 221  POLYGON ((11571007.301 146270.809, 11570994.34...
# 223  POLYGON ((11570638.385 146230.609, 11570633.54...

# %%
# ordered list of brown line station coordinates
brown_line_stations_gdf['coordinates'] = brown_line_stations_gdf['geometry'].centroid
brown_line_stations_gdf

# create a linestring for the brown line route
from shapely.geometry import LineString
brown_line_route = LineString(brown_line_stations_gdf['coordinates'])

# %%
from shapely.geometry import LineString

# combine bus routes
bus_routes_combined = bus_routes_gdf_3857.groupby(['ServiceNo', 'Direction']).apply(lambda x: LineString(x.geometry.tolist())).reset_index()
bus_routes_combined.columns = ['ServiceNo', 'Direction', 'geometry']
bus_routes_combined
# Out:
# /var/folders/d0/twkl0gkd7lv67r2q_sxfmpnw0000gn/T/ipykernel_35887/1680479668.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   bus_routes_combined = bus_routes_gdf_3857.groupby(['ServiceNo', 'Direction']).apply(lambda x: LineString(x.geometry.tolist())).reset_index()
#     ServiceNo  Direction                                           geometry
# 0          10          1  LINESTRING (11570925.355747303 150749.03122670...
# 1          10          2  LINESTRING (11551610.561061133 144087.88490860...
# 2         100          1  LINESTRING (11562943.630025776 150347.12028417...
# 3         100          2  LINESTRING (11553774.516701924 145960.08849871...
# 4        100A          1  LINESTRING (11562943.630025776 150347.12028417...
# ..        ...        ...                                                ...
# 719       992          1  LINESTRING (11549515.381030776 150294.50067879...
# 720       992          2  LINESTRING (11547835.02338783 151709.373424986...
# 721       993          1  LINESTRING (11548357.891036088 148329.89223418...
# 722        9A          1  LINESTRING (11569327.609406518 147460.11332459...
# 723        9B          1  LINESTRING (11572046.913672755 149433.61637057...
#
# [724 rows x 3 columns]

# %%
# calculate the overlapping distance of each bus route and the brown line
buffer_distance = 150
buffered_brown_line = brown_line_route.buffer(buffer_distance)

overlap_distance_output = []

for i, route in tqdm(bus_routes_combined.iterrows()):
    overlap = buffered_brown_line.intersection(route.geometry)
    if overlap.is_empty:
        overlap_distance_output.append({
            'Bus Service': route['ServiceNo'],
            'Direction': route['Direction'],
            'Overlap Distance': 0
            })
    else:
        overlap_distance_output.append({
            'Bus Service': route['ServiceNo'],
            'Direction': route['Direction'],
            'Overlap Distance': overlap.length
            })

overlap_distance = pd.DataFrame(overlap_distance_output)
overlap_distance
# Out:
# 724it [00:00, 3534.36it/s]
#     Bus Service  Direction  Overlap Distance
# 0            10          1        303.158745
# 1            10          2        304.681655
# 2           100          1        303.158745
# 3           100          2        305.338292
# 4          100A          1          0.000000
# ..          ...        ...               ...
# 719         992          1          0.000000
# 720         992          2          0.000000
# 721         993          1          0.000000
# 722          9A          1          0.000000
# 723          9B          1          0.000000
#
# [724 rows x 3 columns]

# %%
# filter bus routes with overlap
bus_routes_overlap = overlap_distance[overlap_distance['Overlap Distance'] > 0].sort_values(by = 'Overlap Distance', ascending = False)
bus_routes_overlap
# Out:
#     Bus Service  Direction  Overlap Distance
# 349          36          1      13497.671113
# 351         36B          1      11775.414400
# 392          47          1       6834.465678
# 225        196e          1       6707.001743
# 350         36A          1       6150.759588
# ..          ...        ...               ...
# 182         178          1        125.862879
# 183         178          2        124.004316
# 619        911A          1        104.939940
# 552        851e          1         46.125602
# 109        147A          1         46.125602
#
# [321 rows x 3 columns]

# %% [markdown]
# # Blue Line

# %%
blue_line = [
    'SUNGEI KADUT MRT STATION', 'BUKIT PANJANG MRT STATION', 'CASHEW MRT STATION', 'HILLVIEW MRT STATION', 'HUME MRT STATION', 'BEAUTY WORLD MRT STATION', 'KING ALBERT PARK MRT STATION', 
    'SIXTH AVENUE MRT STATION', 'TAN KAH KEE MRT STATION', 'BOTANIC GARDENS MRT STATION', 'STEVENS MRT STATION', 'NEWTON MRT STATION', 
    'LITTLE INDIA MRT STATION', 'ROCHOR MRT STATION', 'BUGIS MRT STATION', 'PROMENADE MRT STATION', 'BAYFRONT MRT STATION', 'DOWNTOWN MRT STATION', 'TELOK AYER MRT STATION', 
    'CHINATOWN MRT STATION', 'FORT CANNING MRT STATION', 'BENCOOLEN MRT STATION', 'JALAN BESAR MRT STATION', 'BENDEMEER MRT STATION', 
    'GEYLANG BAHRU MRT STATION', 'MATTAR MRT STATION', 'MACPHERSON MRT STATION', 'UBI MRT STATION', 'KAKI BUKIT MRT STATION', 'BEDOK NORTH MRT STATION', 
    'BEDOK RESERVOIR MRT STATION', 'TAMPINES WEST MRT STATION', 'TAMPINES MRT STATION', 'TAMPINES EAST MRT STATION', 'UPPER CHANGI MRT STATION', 'EXPO MRT STATION'
]

# filter brown line stations from mrt stations geodataframe
blue_line_stations_gdf = mrt_stations_gdf_3857[mrt_stations_gdf_3857['STN_NAM_DE'].isin(blue_line)]

# order brown line stations based on list
blue_line_stations_gdf['STN_NAM_DE'] = pd.Categorical(blue_line_stations_gdf['STN_NAM_DE'],
                                                       categories = blue_line,
                                                       ordered = True)
blue_line_stations_gdf = blue_line_stations_gdf.sort_values('STN_NAM_DE')
blue_line_stations_gdf
# Out:
#      TYP_CD STN_NAM                     ATTACHEMEN TYP_CD_DES  \
# 4         0    None                           None        MRT
# 5         0    None                           None        MRT
# 1         0    None                           None        MRT
# 3         0    None                           None        MRT
# 2         0    None                           None        MRT
# 67        0    None                           None        MRT
# 33        0    None                           None        MRT
# 216       0    None                           None        MRT
# 125       0    None                           None        MRT
# 108       0    None               CC19_BTN STN.zip        MRT
# 32        0    None                           None        MRT
# 203       0    None                           None        MRT
# 112       0    None                           None        MRT
# 167       0    None                           None        MRT
# 68        0    None                           None        MRT
# 89        0    None                NE7_LTI STN.zip        MRT
# 69        0    None                           None        MRT
# 156       0    None                           None        MRT
# 83        0    None  C301A_S_BGS_MAIN_A_R19_P2.zip        MRT
# 126       0    None                           None        MRT
# 76        0    None                CC4_PMN STN.zip        MRT
# 99        0    None                           None        MRT
# 170       0    None                           None        MRT
# 179       0    None                           None        MRT
# 169       0    None                           None        MRT
# 92        0    None                NE4_CNT STN.zip        MRT
# 94        0    None                           None        MRT
# 93        0    None                           None        MRT
# 97        0    None                           None        MRT
# 172       0    None                           None        MRT
# 171       0    None                           None        MRT
# 98        0    None                           None        MRT
# 39        0    None               CC10_MPS STN.zip        MRT
# 189       0    None                           None        MRT
# 181       0    None                           None        MRT
# 95        0    None                           None        MRT
# 102       0    None                           None        MRT
# 103       0    None                           None        MRT
# 26        0    None                           None        MRT
# 27        0    None                           None        MRT
# 96        0    None                           None        MRT
# 28        0    None                           None        MRT
# 178       0    None                           None        MRT
# 40        0    None   C504_S_CGA_MAIN_A_R19_P2.zip        MRT
# 130       0    None                           None        MRT
#
#                        STN_NAM_DE  \
# 4       BUKIT PANJANG MRT STATION
# 5              CASHEW MRT STATION
# 1            HILLVIEW MRT STATION
# 3                HUME MRT STATION
# 2        BEAUTY WORLD MRT STATION
# 67   KING ALBERT PARK MRT STATION
# 33       SIXTH AVENUE MRT STATION
# 216       TAN KAH KEE MRT STATION
# 125   BOTANIC GARDENS MRT STATION
# 108   BOTANIC GARDENS MRT STATION
# 32            STEVENS MRT STATION
# 203           STEVENS MRT STATION
# 112            NEWTON MRT STATION
# 167            NEWTON MRT STATION
# 68       LITTLE INDIA MRT STATION
# 89       LITTLE INDIA MRT STATION
# 69             ROCHOR MRT STATION
# 156             BUGIS MRT STATION
# 83              BUGIS MRT STATION
# 126         PROMENADE MRT STATION
# 76          PROMENADE MRT STATION
# 99           BAYFRONT MRT STATION
# 170          DOWNTOWN MRT STATION
# 179        TELOK AYER MRT STATION
# 169         CHINATOWN MRT STATION
# 92          CHINATOWN MRT STATION
# 94       FORT CANNING MRT STATION
# 93          BENCOOLEN MRT STATION
# 97        JALAN BESAR MRT STATION
# 172         BENDEMEER MRT STATION
# 171     GEYLANG BAHRU MRT STATION
# 98             MATTAR MRT STATION
# 39         MACPHERSON MRT STATION
# 189        MACPHERSON MRT STATION
# 181               UBI MRT STATION
# 95         KAKI BUKIT MRT STATION
# 102       BEDOK NORTH MRT STATION
# 103   BEDOK RESERVOIR MRT STATION
# 26      TAMPINES WEST MRT STATION
# 27           TAMPINES MRT STATION
# 96           TAMPINES MRT STATION
# 28      TAMPINES EAST MRT STATION
# 178      UPPER CHANGI MRT STATION
# 40               EXPO MRT STATION
# 130              EXPO MRT STATION
#
#                                               geometry
# 4    POLYGON ((11550666.118 153603.709, 11550698.62...
# 5    POLYGON ((11551010.357 152545.896, 11551024.66...
# 1    POLYGON ((11551320.421 151685.479, 11551324.86...
# 3    POLYGON ((11551478.151 150855.083, 11551485.53...
# 2    POLYGON ((11552265.127 149269.279, 11552255.26...
# 67   POLYGON ((11553177.948 148708.332, 11553217.08...
# 33   POLYGON ((11554594.564 148204.756, 11554598.90...
# 216  POLYGON ((11555673.915 147692.277, 11555708.09...
# 125  POLYGON ((11556730.423 147258.342, 11556757.97...
# 108  POLYGON ((11556592.183 147107.790, 11556577.02...
# 32   POLYGON ((11557812.324 147000.057, 11557816.70...
# 203  POLYGON ((11557783.878 146982.248, 11557809.15...
# 112  POLYGON ((11559141.244 146029.212, 11559129.33...
# 167  POLYGON ((11559262.161 146203.068, 11559266.61...
# 68   POLYGON ((11560316.352 145570.701, 11560318.56...
# 89   POLYGON ((11560413.038 145370.024, 11560470.54...
# 69   POLYGON ((11560865.734 145197.301, 11560865.51...
# 156  POLYGON ((11561380.492 144536.847, 11561377.30...
# 83   POLYGON ((11561117.325 144671.825, 11561108.96...
# 126  POLYGON ((11561725.013 144035.618, 11561732.57...
# 76   POLYGON ((11561749.024 144127.673, 11561774.92...
# 99   POLYGON ((11561461.428 142616.067, 11561497.76...
# 170  POLYGON ((11560791.152 142451.968, 11560797.06...
# 179  POLYGON ((11560253.727 142793.695, 11560266.90...
# 169  POLYGON ((11559751.172 143121.613, 11559752.03...
# 92   POLYGON ((11559695.295 142864.198, 11559671.98...
# 94   POLYGON ((11559850.531 143853.090, 11559849.74...
# 93   POLYGON ((11560448.956 144464.408, 11560442.42...
# 97   POLYGON ((11561097.782 145255.815, 11561076.36...
# 172  POLYGON ((11561891.820 146236.143, 11561957.84...
# 171  POLYGON ((11562901.907 147107.273, 11562944.33...
# 98   POLYGON ((11564156.892 147735.796, 11564172.62...
# 39   POLYGON ((11564984.421 147762.740, 11565009.65...
# 189  POLYGON ((11564805.740 147521.951, 11564804.08...
# 181  POLYGON ((11565941.773 148055.245, 11565985.04...
# 95   POLYGON ((11567109.583 148647.732, 11567105.32...
# 102  POLYGON ((11568235.960 148526.885, 11568207.39...
# 103  POLYGON ((11569569.134 148831.286, 11569748.84...
# 26   POLYGON ((11570351.513 149790.978, 11570353.81...
# 27   POLYGON ((11571164.394 150577.160, 11571131.41...
# 96   POLYGON ((11570846.566 150813.451, 11570821.24...
# 28   POLYGON ((11572232.918 150930.267, 11572232.84...
# 178  POLYGON ((11572972.936 149532.939, 11573003.92...
# 40   POLYGON ((11572969.696 148589.449, 11572969.69...
# 130  POLYGON ((11572896.654 148470.542, 11572873.05...

# %%
# ordered list of brown line station coordinates
blue_line_stations_gdf['coordinates'] = blue_line_stations_gdf['geometry'].centroid
blue_line_stations_gdf

# create a linestring for the brown line route
from shapely.geometry import LineString
blue_line_route = LineString(blue_line_stations_gdf['coordinates'])

# %%
from shapely.geometry import LineString

# combine bus routes
bus_routes_combined = bus_routes_gdf_3857.groupby(['ServiceNo', 'Direction']).apply(lambda x: LineString(x.geometry.tolist())).reset_index()
bus_routes_combined.columns = ['ServiceNo', 'Direction', 'geometry']
bus_routes_combined
# Out:
#     ServiceNo  Direction                                           geometry
# 0          10          1  LINESTRING (11570925.355747303 150749.03122670...
# 1          10          2  LINESTRING (11551610.561061133 144087.88490860...
# 2         100          1  LINESTRING (11562943.630025776 150347.12028417...
# 3         100          2  LINESTRING (11553774.516701924 145960.08849871...
# 4        100A          1  LINESTRING (11562943.630025776 150347.12028417...
# ..        ...        ...                                                ...
# 719       992          1  LINESTRING (11549515.381030776 150294.50067879...
# 720       992          2  LINESTRING (11547835.02338783 151709.373424986...
# 721       993          1  LINESTRING (11548357.891036088 148329.89223418...
# 722        9A          1  LINESTRING (11569327.609406518 147460.11332459...
# 723        9B          1  LINESTRING (11572046.913672755 149433.61637057...
#
# [724 rows x 3 columns]

# %%
# calculate the overlapping distance of each bus route and the brown line
buffer_distance = 150
buffered_blue_line = blue_line_route.buffer(buffer_distance)

overlap_distance_output = []

for i, route in tqdm(bus_routes_combined.iterrows()):
    overlap = buffered_blue_line.intersection(route.geometry)
    if overlap.is_empty:
        overlap_distance_output.append({
            'Bus Service': route['ServiceNo'],
            'Direction': route['Direction'],
            'Overlap Distance': 0
            })
    else:
        overlap_distance_output.append({
            'Bus Service': route['ServiceNo'],
            'Direction': route['Direction'],
            'Overlap Distance': overlap.length
            })

overlap_distance_blue = pd.DataFrame(overlap_distance_output)
overlap_distance_blue
# Out:
# 724it [00:00, 4848.19it/s]
#     Bus Service  Direction  Overlap Distance
# 0            10          1       1085.722634
# 1            10          2       1091.514007
# 2           100          1        914.021723
# 3           100          2        914.707723
# 4          100A          1        304.650635
# ..          ...        ...               ...
# 719         992          1          0.000000
# 720         992          2          0.000000
# 721         993          1          0.000000
# 722          9A          1       1183.825625
# 723          9B          1       1183.825625
#
# [724 rows x 3 columns]

# %%
# filter bus routes with overlap with blue line
bus_routes_overlap_blue = overlap_distance_blue[overlap_distance_blue['Overlap Distance'] > 0].sort_values(by = 'Overlap Distance', ascending = False)
bus_routes_overlap_blue
# Out:
#     Bus Service  Direction  Overlap Distance
# 478          67          2      16091.462313
# 477          67          1      14353.211924
# 164         170          1      13688.136207
# 252          23          1      12961.825736
# 165         170          2      12815.664331
# ..          ...        ...               ...
# 53          123          2        191.817440
# 63         129A          1         30.953370
# 629         920          1         10.275598
# 630         922          1         10.275598
# 684        973A          1          3.775807
#
# [385 rows x 3 columns]

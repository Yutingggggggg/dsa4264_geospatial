# %%
# %run data.ipynb
# Out:
# ['https://ltafarecard.s3.ap-southeast-1.amazonaws.com/202409/origin_destination_bus_202409.zip?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEJL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDmFwLXNvdXRoZWFzdC0xIkYwRAIgWWvlHEpDYbIqsA9cAmNU%2BPcgnU6eitLeVRNyYng%2FEOUCIDZ1ny05CUD6hk7rFyO2YpcBxk5ueomQctHmgwyh6trYKssFCPv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEQBBoMMzQwNjQ1MzgxMzA0Igzn%2Bbj52SDYl3McWg4qnwXAc5AwnyMRuctJYYhjFCv9GQd2F6VVhpben6V5zcH0xxKGUbPF0K9WehGII8dpCg%2BliHMlnkoUPMdwphplUNJi0gVjWBq1GvVn5%2FpHIYgXRT3MVlSWWUF3%2Bc3mwreHUdldYk3h8Z5Bexyltl1VARm3TukO1BNiJf6%2Fj2wmnPxmT9IPkP6hrbS6k743ceDvORBJhBPWre36CQ6JLpDFernW6PDtbgVGKzGp11Lcv4QuAlOhQ3CaActviGHUtWn9PLagbMioQnLKq33Z%2BAg2jrZnUXON05%2FNP2Dk4LYUlQQLR0Iwds%2F5yadWCGnJhGZ%2BTd4I4bMxCYJRIX0bK7ZCTRaoD16r4vMf6rFohhOS9Gm2x5Q6xmxWgmnipPTodKRH3BuF0d2qYxUVbYNMqkV2f92IqmLQ2g3iw5IXajzHUDSU5a5gYRM4sSDh2k8Q1pi%2Fmt%2BeyQz8%2F0gdKIzko4982EKQBQVFUfTNXlazCzmXk1DuK4oKMEn2VficESy6aWcub6QvvLWji6TB2tkRpvpYrXsch37LUjDbgwAo%2BLzPyaa3BT%2F5UYLiFsQXYZBe%2BtaFejR5I78WFfW%2BNVhzhy%2FuR%2Bko4KiPWLksDD%2BpQJjtpJprnqStbtTN542pjKGy6y3gct7kLS4xN7lnmzaKndWWb6JwIchVn%2BDoV09WjmHv2IXH%2FhIigAm3UBUARULoJgi8gaeTiZWQibMaTUXD0%2FRxQBcZHzJ9f9xAIs4Hr8hHvsDPjeVrS2E1oC20Qjy1IgGrrAwb%2FJY%2Fp2M88x7Awll%2BLBjLMXjtFeIHBPMYhnjLpado7CT%2Fr%2Br8Opct6uyFE2EpK9jbzsTam%2BtTtlohlGJR0WsV3oOw%2FIhFtvoXiqc4%2Fe5j6iuQ3wboEtEpZAUpL45NFTDunfG4BjqyATiWlv%2BhOCC7vcPQO%2BP8GzyZg0HTq456Nu5SAw1YTNHW1CP2noex%2B44TshEwy6SpTM9FNFG2LwmwXz5%2F7C3PVjPo4uFqKvlx4oUWiU%2BTFewxSg9UxSMBH9Kf%2BlobDDgazI6i8TZpdbTkdRvN8UrmD7h4Ynod7v3oUynXTuoOYrP5HNauCItjebZRgj6JRUiHaztoAy%2FtRnvY8W9A%2ByQ%2BwIFvDawypOr8L%2FudDrOwtPu53KQ%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20241026T034156Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAU6UAMAS4NERYIPA7%2F20241026%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=d35a8e9e4eb49153edc465ea977fa62a3b4798a7b0d2fb87f4d7f48ca5c299e6']
# ['https://ltafarecard.s3.ap-southeast-1.amazonaws.com/202409/origin_destination_train_202409.zip?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEJP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDmFwLXNvdXRoZWFzdC0xIkgwRgIhAK%2BMuxb5wtwl3jovfDKc0v6UAi5%2B3gqU48x6BZL1Opy2AiEAkljyeLxIfyHW6GSdVif6inVBTKTL5SsS6i6n2c8mgUwqywUI%2FP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAEGgwzNDA2NDUzODEzMDQiDCe%2FmDvef6lEIAnflSqfBc%2BBeRZm0FJafeiN2KoJh5yLVNc78GdYNQZ8nwvYJRkeySw1SMt6MwIU0wBGXvOnzrMjILP7UgqGjKXAukIr4mffIHnmvMGXroPH%2FfKfc0%2BYYw09y4uR4hz4fQmffnJhn9OB2xjvvQpUjETU5kcebCPwSfcJ6voVg39m68Ck%2B7ylrGRw6QfwvQewmHn0GOgG%2FSEfeeWl7A9eq3CUL5tJtxyeASq2xFtOCeQjgwWXoAMJd2QXhYLNzu7lMJQlRm7LQ1Nv%2B%2Ffm%2FhARcf2GwiA8wjNnTb7IMJ%2BWLz9H40HGRuPDfNoLh8sqf9MmYD%2BsaYfTNxEhNodNIgTUbu2hdmlPwWo9sEctp3g24x9wjjEyEjODB4iSlk0Eq%2B7yTYh3kBgQBgNg8%2Fr8HCuRr08XoPCfiWnYAR5O1WGf7u9%2B1nzwsV%2BVqGRRlbFSOZH6bXNFhuWBVRWrSWZBS9R%2Fh2Gh2WhpC%2BCgCHkC9LMKphKQXj34RNgYF6o8TD%2BwVQYSQbA7hfvQLiwsVJqKHnHZoiW2%2BK%2FkSW5VLXsQDNQ306bt7EZhYFqU%2BQhJjrzWg%2F4eFJq5hdroIq8GznIc2ZJh8R9L4BfCGcOzeevE2ATgXscB7QHPWGKJBb5fycgOUuzF6VaANDj238xzYSX997yNw50dVY7D0wHMGqxIR9v7wqX1jLoP3DpxAqiUDotvyxwitOKqEcDhPOuxcEHWjmBzriFcnyXGQRpIDWqUdKvSdPV05lwxcJpXIYoQd1XYJlKt6jrGIk48pAwNXdO0Dl38%2Bg%2Bj%2BxVDKBIHPMGzp%2BL3xDB%2B3OTxD2uyyOpIyb%2BLmMnWtpjhOGChRdsKjW5yYPap2Jn2Ktt7lkIA9DrcLiiKsMHiHTujV1acc%2Bl1w3keIUwdynwrAEhVMKWo8bgGOrAB6wJY01xCFW0qpnuEdCF7j9b2jw4i2PqPBsN%2FMnHnF3n%2F7p%2BMp7wHzhSOuiXyX5l7l%2FWi0pkrHNw4LartdOd4xtxjp1uqkVMbscEDHZVXAKIg9%2F4kC%2B8AP%2BTxaGqdmr3BB13Rrn6QNcV8PhuOsd0eJVGFSgn6jNJPTlQJ%2B8b2PNV8kZxPDapu%2FoV2E5Qfc%2BLlqo0yEXsrXR5lP9HErBo9ZyrsNW8N%2FQHEHPsv%2B7ctbWU%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20241026T034205Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAU6UAMAS4KG2P4O4B%2F20241026%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=8da7737e617253a1f26fe2f57326f573427058be087e2260649cea227108a52f']

# %%
# %run nearest_mrt_station_to_bus_stops.ipynb
# Out:
# ['https://ltafarecard.s3.ap-southeast-1.amazonaws.com/202409/origin_destination_bus_202409.zip?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEJL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDmFwLXNvdXRoZWFzdC0xIkYwRAIgWWvlHEpDYbIqsA9cAmNU%2BPcgnU6eitLeVRNyYng%2FEOUCIDZ1ny05CUD6hk7rFyO2YpcBxk5ueomQctHmgwyh6trYKssFCPv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEQBBoMMzQwNjQ1MzgxMzA0Igzn%2Bbj52SDYl3McWg4qnwXAc5AwnyMRuctJYYhjFCv9GQd2F6VVhpben6V5zcH0xxKGUbPF0K9WehGII8dpCg%2BliHMlnkoUPMdwphplUNJi0gVjWBq1GvVn5%2FpHIYgXRT3MVlSWWUF3%2Bc3mwreHUdldYk3h8Z5Bexyltl1VARm3TukO1BNiJf6%2Fj2wmnPxmT9IPkP6hrbS6k743ceDvORBJhBPWre36CQ6JLpDFernW6PDtbgVGKzGp11Lcv4QuAlOhQ3CaActviGHUtWn9PLagbMioQnLKq33Z%2BAg2jrZnUXON05%2FNP2Dk4LYUlQQLR0Iwds%2F5yadWCGnJhGZ%2BTd4I4bMxCYJRIX0bK7ZCTRaoD16r4vMf6rFohhOS9Gm2x5Q6xmxWgmnipPTodKRH3BuF0d2qYxUVbYNMqkV2f92IqmLQ2g3iw5IXajzHUDSU5a5gYRM4sSDh2k8Q1pi%2Fmt%2BeyQz8%2F0gdKIzko4982EKQBQVFUfTNXlazCzmXk1DuK4oKMEn2VficESy6aWcub6QvvLWji6TB2tkRpvpYrXsch37LUjDbgwAo%2BLzPyaa3BT%2F5UYLiFsQXYZBe%2BtaFejR5I78WFfW%2BNVhzhy%2FuR%2Bko4KiPWLksDD%2BpQJjtpJprnqStbtTN542pjKGy6y3gct7kLS4xN7lnmzaKndWWb6JwIchVn%2BDoV09WjmHv2IXH%2FhIigAm3UBUARULoJgi8gaeTiZWQibMaTUXD0%2FRxQBcZHzJ9f9xAIs4Hr8hHvsDPjeVrS2E1oC20Qjy1IgGrrAwb%2FJY%2Fp2M88x7Awll%2BLBjLMXjtFeIHBPMYhnjLpado7CT%2Fr%2Br8Opct6uyFE2EpK9jbzsTam%2BtTtlohlGJR0WsV3oOw%2FIhFtvoXiqc4%2Fe5j6iuQ3wboEtEpZAUpL45NFTDunfG4BjqyATiWlv%2BhOCC7vcPQO%2BP8GzyZg0HTq456Nu5SAw1YTNHW1CP2noex%2B44TshEwy6SpTM9FNFG2LwmwXz5%2F7C3PVjPo4uFqKvlx4oUWiU%2BTFewxSg9UxSMBH9Kf%2BlobDDgazI6i8TZpdbTkdRvN8UrmD7h4Ynod7v3oUynXTuoOYrP5HNauCItjebZRgj6JRUiHaztoAy%2FtRnvY8W9A%2ByQ%2BwIFvDawypOr8L%2FudDrOwtPu53KQ%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20241026T034541Z&X-Amz-SignedHeaders=host&X-Amz-Expires=299&X-Amz-Credential=ASIAU6UAMAS4NERYIPA7%2F20241026%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=09cbbac4faf834078094e3eb001429dceb2970cce7bfa3f0de23fa62db5b06ca']
# ['https://ltafarecard.s3.ap-southeast-1.amazonaws.com/202409/origin_destination_train_202409.zip?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEJL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDmFwLXNvdXRoZWFzdC0xIkYwRAIgWWvlHEpDYbIqsA9cAmNU%2BPcgnU6eitLeVRNyYng%2FEOUCIDZ1ny05CUD6hk7rFyO2YpcBxk5ueomQctHmgwyh6trYKssFCPv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEQBBoMMzQwNjQ1MzgxMzA0Igzn%2Bbj52SDYl3McWg4qnwXAc5AwnyMRuctJYYhjFCv9GQd2F6VVhpben6V5zcH0xxKGUbPF0K9WehGII8dpCg%2BliHMlnkoUPMdwphplUNJi0gVjWBq1GvVn5%2FpHIYgXRT3MVlSWWUF3%2Bc3mwreHUdldYk3h8Z5Bexyltl1VARm3TukO1BNiJf6%2Fj2wmnPxmT9IPkP6hrbS6k743ceDvORBJhBPWre36CQ6JLpDFernW6PDtbgVGKzGp11Lcv4QuAlOhQ3CaActviGHUtWn9PLagbMioQnLKq33Z%2BAg2jrZnUXON05%2FNP2Dk4LYUlQQLR0Iwds%2F5yadWCGnJhGZ%2BTd4I4bMxCYJRIX0bK7ZCTRaoD16r4vMf6rFohhOS9Gm2x5Q6xmxWgmnipPTodKRH3BuF0d2qYxUVbYNMqkV2f92IqmLQ2g3iw5IXajzHUDSU5a5gYRM4sSDh2k8Q1pi%2Fmt%2BeyQz8%2F0gdKIzko4982EKQBQVFUfTNXlazCzmXk1DuK4oKMEn2VficESy6aWcub6QvvLWji6TB2tkRpvpYrXsch37LUjDbgwAo%2BLzPyaa3BT%2F5UYLiFsQXYZBe%2BtaFejR5I78WFfW%2BNVhzhy%2FuR%2Bko4KiPWLksDD%2BpQJjtpJprnqStbtTN542pjKGy6y3gct7kLS4xN7lnmzaKndWWb6JwIchVn%2BDoV09WjmHv2IXH%2FhIigAm3UBUARULoJgi8gaeTiZWQibMaTUXD0%2FRxQBcZHzJ9f9xAIs4Hr8hHvsDPjeVrS2E1oC20Qjy1IgGrrAwb%2FJY%2Fp2M88x7Awll%2BLBjLMXjtFeIHBPMYhnjLpado7CT%2Fr%2Br8Opct6uyFE2EpK9jbzsTam%2BtTtlohlGJR0WsV3oOw%2FIhFtvoXiqc4%2Fe5j6iuQ3wboEtEpZAUpL45NFTDunfG4BjqyATiWlv%2BhOCC7vcPQO%2BP8GzyZg0HTq456Nu5SAw1YTNHW1CP2noex%2B44TshEwy6SpTM9FNFG2LwmwXz5%2F7C3PVjPo4uFqKvlx4oUWiU%2BTFewxSg9UxSMBH9Kf%2BlobDDgazI6i8TZpdbTkdRvN8UrmD7h4Ynod7v3oUynXTuoOYrP5HNauCItjebZRgj6JRUiHaztoAy%2FtRnvY8W9A%2ByQ%2BwIFvDawypOr8L%2FudDrOwtPu53KQ%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20241026T034547Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAU6UAMAS4NERYIPA7%2F20241026%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=a151c430530107f0235277e873f88b59129c4c635eab4d5ddc0c3b934ea30679']
# 25544it [00:16, 1553.09it/s]

# %%
# mrt stations geodataframe
import os
os.environ['OGR_GEOMETRY_ACCEPT_UNCLOSED_RING'] = 'NO'

mrt_stations_gdf = geopandas.read_file('./TrainStation_Jul2024/RapidTransitSystemStation.shp')
mrt_stations_gdf_3857 = mrt_stations_gdf.to_crs(3857)
mrt_stations_gdf_3857
# Out:
#      TYP_CD STN_NAM ATTACHEMEN TYP_CD_DES                      STN_NAM_DE  \
# 0         0    None       None        MRT                 GALI BATU DEPOT
# 1         0    None       None        MRT            HILLVIEW MRT STATION
# 2         0    None       None        MRT        BEAUTY WORLD MRT STATION
# 3         0    None       None        MRT                HUME MRT STATION
# 4         0    None       None        MRT       BUKIT PANJANG MRT STATION
# ..      ...     ...        ...        ...                             ...
# 225       0    None       None        MRT         KATONG PARK MRT STATION
# 226       0    None       None        MRT      MARINE TERRACE MRT STATION
# 227       0    None       None        MRT         TANJONG RHU MRT STATION
# 228       0    None       None        MRT       MARINE PARADE MRT STATION
# 229       0    None       None        MRT  FOUNDERS' MEMORIAL MRT STATION
#
#                                               geometry
# 0    POLYGON ((11549880.181 155286.262, 11549893.09...
# 1    POLYGON ((11551320.421 151685.479, 11551324.86...
# 2    POLYGON ((11552265.127 149269.279, 11552255.26...
# 3    POLYGON ((11551478.151 150855.083, 11551485.53...
# 4    POLYGON ((11550666.118 153603.709, 11550698.62...
# ..                                                 ...
# 225  POLYGON ((11564432.509 144548.028, 11564447.75...
# 226  POLYGON ((11567908.523 145472.086, 11567908.42...
# 227  POLYGON ((11563110.672 144334.178, 11563108.03...
# 228  POLYGON ((11566600.443 144955.407, 11566582.69...
# 229  POLYGON ((11562591.609 143792.727, 11562595.94...
#
# [230 rows x 6 columns]

# %%
brown_line = ['WOODLANDS NORTH MRT STATION', 'WOODLANDS MRT STATION', 'WOODLANDS SOUTH MRT STATION',
              'SPRINGLEAF MRT STATION', 'LENTOR MRT STATION', 'MAYFLOWER MRT STATION',
              'BRIGHT HILL MRT STATION', 'UPPER THOMSON MRT STATION', 'CALDECOTT MRT STATION',
              'STEVENS MRT STATION', 'NAPIER MRT STATION', 'ORCHARD BOULEVARD MRT STATION',
              'ORCHARD MRT STATION', 'GREAT WORLD MRT STATION', 'HAVELOCK MRT STATION',
              'OUTRAM PARK MRT STATION', 'MAXWELL MRT STATION', 'SHENTON WAY MRT STATION',
              'MARINA BAY MRT STATION', 'GARDENS BY THE BAY MRT STATION', 'TANJONG RHU MRT STATION',
              'KATONG PARK MRT STATION', 'TANJONG KATONG MRT STATION', 'MARINE PARADE MRT STATION',
              'MARINE TERRACE MRT STATION', 'SIGLAP MRT STATION', 'BAYSHORE MRT STATION',
              'BEDOK SOUTH MRT STATION', 'SUNGEI BEDOK MRT STATION']

# filter brown line stations from mrt stations geodataframe
brown_line_stations_gdf = mrt_stations_gdf_3857[mrt_stations_gdf_3857['STN_NAM_DE'].isin(brown_line)]

# order brown line stations based on list
brown_line_stations_gdf['STN_NAM_DE'] = pd.Categorical(brown_line_stations_gdf['STN_NAM_DE'],
                                                       categories = brown_line,
                                                       ordered = True)
brown_line_stations_gdf = brown_line_stations_gdf.sort_values('STN_NAM_DE')
brown_line_stations_gdf
# Out:
#      TYP_CD STN_NAM                    ATTACHEMEN TYP_CD_DES  \
# 192       0    None                          None        MRT
# 196       0    None                          None        MRT
# 177       0    None                          None        MRT
# 191       0    None                          None        MRT
# 187       0    None                          None        MRT
# 110       0    None                          None        MRT
# 219       0    None                          None        MRT
# 186       0    None                          None        MRT
# 217       0    None                          None        MRT
# 218       0    None                          None        MRT
# 109       0    None              CC17_CDT STN.zip        MRT
# 32        0    None                          None        MRT
# 203       0    None                          None        MRT
# 204       0    None                          None        MRT
# 212       0    None                          None        MRT
# 213       0    None                          None        MRT
# 104       0    None                          None        MRT
# 209       0    None                          None        MRT
# 202       0    None                          None        MRT
# 201       0    None                          None        MRT
# 84        0    None  C109_S_OTP_MAIN_A_R19_P2.zip        MRT
# 117       0    None               NE3_OTP STN.zip        MRT
# 210       0    None                          None        MRT
# 206       0    None                          None        MRT
# 64        0    None               CE2_MRB STN.zip        MRT
# 200       0    None                          None        MRT
# 115       0    None                          None        MRT
# 211       0    None                          None        MRT
# 208       0    None                          None        MRT
# 227       0    None                          None        MRT
# 225       0    None                          None        MRT
# 224       0    None                          None        MRT
# 222       0    None                          None        MRT
# 228       0    None                          None        MRT
# 226       0    None                          None        MRT
# 220       0    None                          None        MRT
# 221       0    None                          None        MRT
# 223       0    None                          None        MRT
#
#                          STN_NAM_DE  \
# 192     WOODLANDS NORTH MRT STATION
# 196           WOODLANDS MRT STATION
# 177           WOODLANDS MRT STATION
# 191     WOODLANDS SOUTH MRT STATION
# 187          SPRINGLEAF MRT STATION
# 110              LENTOR MRT STATION
# 219           MAYFLOWER MRT STATION
# 186         BRIGHT HILL MRT STATION
# 217       UPPER THOMSON MRT STATION
# 218           CALDECOTT MRT STATION
# 109           CALDECOTT MRT STATION
# 32              STEVENS MRT STATION
# 203             STEVENS MRT STATION
# 204              NAPIER MRT STATION
# 212   ORCHARD BOULEVARD MRT STATION
# 213             ORCHARD MRT STATION
# 104             ORCHARD MRT STATION
# 209         GREAT WORLD MRT STATION
# 202            HAVELOCK MRT STATION
# 201         OUTRAM PARK MRT STATION
# 84          OUTRAM PARK MRT STATION
# 117         OUTRAM PARK MRT STATION
# 210             MAXWELL MRT STATION
# 206         SHENTON WAY MRT STATION
# 64           MARINA BAY MRT STATION
# 200          MARINA BAY MRT STATION
# 115          MARINA BAY MRT STATION
# 211          MARINA BAY MRT STATION
# 208  GARDENS BY THE BAY MRT STATION
# 227         TANJONG RHU MRT STATION
# 225         KATONG PARK MRT STATION
# 224      TANJONG KATONG MRT STATION
# 222       MARINE PARADE MRT STATION
# 228       MARINE PARADE MRT STATION
# 226      MARINE TERRACE MRT STATION
# 220              SIGLAP MRT STATION
# 221            BAYSHORE MRT STATION
# 223            BAYSHORE MRT STATION
#
#                                               geometry
# 192  POLYGON ((11553290.504 161340.499, 11553308.78...
# 196  POLYGON ((11553655.571 159844.445, 11553714.07...
# 177  POLYGON ((11553305.733 159892.909, 11553302.44...
# 191  POLYGON ((11554340.403 158819.168, 11554344.10...
# 187  POLYGON ((11556983.209 155700.488, 11556972.59...
# 110  POLYGON ((11559127.808 154037.405, 11559127.68...
# 219  POLYGON ((11559099.098 152920.462, 11559094.58...
# 186  POLYGON ((11558731.827 151811.306, 11558686.82...
# 217  POLYGON ((11558480.214 150916.092, 11558483.67...
# 218  POLYGON ((11559462.068 148993.215, 11559463.61...
# 109  POLYGON ((11559344.392 148875.759, 11559342.18...
# 32   POLYGON ((11557812.324 147000.057, 11557816.70...
# 203  POLYGON ((11557783.878 146982.248, 11557809.15...
# 204  POLYGON ((11557084.982 145522.798, 11557083.15...
# 212  POLYGON ((11557609.258 145103.847, 11557596.44...
# 213  POLYGON ((11558441.87 145091.118, 11558443.047...
# 104  POLYGON ((11558548.169 145071.964, 11558537.94...
# 209  POLYGON ((11558678.291 144289.546, 11558665.64...
# 202  POLYGON ((11558703.693 143659.583, 11558718.50...
# 201  POLYGON ((11559308.372 142682.402, 11559298.43...
# 84   POLYGON ((11559237.753 142695.209, 11559251.83...
# 117  POLYGON ((11559350.232 142623.057, 11559353.15...
# 210  POLYGON ((11559913.945 142605.655, 11559959.79...
# 206  POLYGON ((11560637.091 142232.533, 11560638.12...
# 64   POLYGON ((11561070.528 141987.904, 11561054.72...
# 200  POLYGON ((11561017.163 142126.143, 11561004.19...
# 115  POLYGON ((11561039.437 141991.719, 11561036.58...
# 211  POLYGON ((11561104.449 141953.568, 11561129.46...
# 208  POLYGON ((11562517.349 142416.142, 11562517.16...
# 227  POLYGON ((11563110.672 144334.178, 11563108.03...
# 225  POLYGON ((11564432.509 144548.028, 11564447.75...
# 224  POLYGON ((11565796.023 144618.481, 11565798.11...
# 222  POLYGON ((11566865.98 145173.875, 11566857.526...
# 228  POLYGON ((11566600.443 144955.407, 11566582.69...
# 226  POLYGON ((11567908.523 145472.086, 11567908.42...
# 220  POLYGON ((11569421.424 145813.022, 11569353.34...
# 221  POLYGON ((11571007.301 146270.809, 11570994.34...
# 223  POLYGON ((11570638.385 146230.609, 11570633.54...

# %%
# ordered list of brown line station coordinates
brown_line_stations_gdf['coordinates'] = brown_line_stations_gdf['geometry'].centroid
brown_line_stations_gdf

# create a linestring for the brown line route
from shapely.geometry import LineString
brown_line_route = LineString(brown_line_stations_gdf['coordinates'])

# %%
from shapely.geometry import LineString

# combine bus routes
bus_routes_combined = bus_routes_gdf_3857.groupby(['ServiceNo', 'Direction']).apply(lambda x: LineString(x.geometry.tolist())).reset_index()
bus_routes_combined.columns = ['ServiceNo', 'Direction', 'geometry']
bus_routes_combined
# Out:
# /var/folders/d0/twkl0gkd7lv67r2q_sxfmpnw0000gn/T/ipykernel_35887/1680479668.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   bus_routes_combined = bus_routes_gdf_3857.groupby(['ServiceNo', 'Direction']).apply(lambda x: LineString(x.geometry.tolist())).reset_index()
#     ServiceNo  Direction                                           geometry
# 0          10          1  LINESTRING (11570925.355747303 150749.03122670...
# 1          10          2  LINESTRING (11551610.561061133 144087.88490860...
# 2         100          1  LINESTRING (11562943.630025776 150347.12028417...
# 3         100          2  LINESTRING (11553774.516701924 145960.08849871...
# 4        100A          1  LINESTRING (11562943.630025776 150347.12028417...
# ..        ...        ...                                                ...
# 719       992          1  LINESTRING (11549515.381030776 150294.50067879...
# 720       992          2  LINESTRING (11547835.02338783 151709.373424986...
# 721       993          1  LINESTRING (11548357.891036088 148329.89223418...
# 722        9A          1  LINESTRING (11569327.609406518 147460.11332459...
# 723        9B          1  LINESTRING (11572046.913672755 149433.61637057...
#
# [724 rows x 3 columns]

# %%
# calculate the overlapping distance of each bus route and the brown line
buffer_distance = 150
buffered_brown_line = brown_line_route.buffer(buffer_distance)

overlap_distance_output = []

for i, route in tqdm(bus_routes_combined.iterrows()):
    overlap = buffered_brown_line.intersection(route.geometry)
    if overlap.is_empty:
        overlap_distance_output.append({
            'Bus Service': route['ServiceNo'],
            'Direction': route['Direction'],
            'Overlap Distance': 0
            })
    else:
        overlap_distance_output.append({
            'Bus Service': route['ServiceNo'],
            'Direction': route['Direction'],
            'Overlap Distance': overlap.length
            })

overlap_distance = pd.DataFrame(overlap_distance_output)
overlap_distance
# Out:
# 724it [00:00, 3534.36it/s]
#     Bus Service  Direction  Overlap Distance
# 0            10          1        303.158745
# 1            10          2        304.681655
# 2           100          1        303.158745
# 3           100          2        305.338292
# 4          100A          1          0.000000
# ..          ...        ...               ...
# 719         992          1          0.000000
# 720         992          2          0.000000
# 721         993          1          0.000000
# 722          9A          1          0.000000
# 723          9B          1          0.000000
#
# [724 rows x 3 columns]

# %%
# filter bus routes with overlap
bus_routes_overlap = overlap_distance[overlap_distance['Overlap Distance'] > 0].sort_values(by = 'Overlap Distance', ascending = False)
bus_routes_overlap
# Out:
#     Bus Service  Direction  Overlap Distance
# 349          36          1      13497.671113
# 351         36B          1      11775.414400
# 392          47          1       6834.465678
# 225        196e          1       6707.001743
# 350         36A          1       6150.759588
# ..          ...        ...               ...
# 182         178          1        125.862879
# 183         178          2        124.004316
# 619        911A          1        104.939940
# 552        851e          1         46.125602
# 109        147A          1         46.125602
#
# [321 rows x 3 columns]
